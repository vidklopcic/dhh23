# %%
import sys
import pandas as pd
import json
import csv
import pickle
from pathlib import Path
from bs4 import BeautifulSoup
import json
import multiprocessing
from tqdm import tqdm
import pandas as pd
import math
import multiprocessing as mp
from bs4 import BeautifulSoup
from collections import defaultdict
from tqdm import tqdm

# %%
with open('artefacts/parlamint_with_embeddings.json', 'r') as f:
    parlamint = json.load(f)
parlamint_es_ga = parlamint['ES-GA']
parlaming_gb = parlamint['GB']
parlamint_hu = parlamint['HU']
parlamint_ua = parlamint['UA']
parlamint_si = parlamint['SI']
parlamints = [
    parlamint_es_ga,
    parlamint_si,
    parlaming_gb,
    parlamint_hu,
    parlamint_ua,
]
artefacts = Path('artefacts/pandas_frames')
artefacts.mkdir(exist_ok=True)

# %%
embedding_files = [
    ('SI', 'ParlaMint_SI_embeddings_truncated.pkl'),
    ('ES-GA', 'ParlaMint_EE_embeddings_truncated.pkl'),
    ('GB', 'ParlaMint_GB_commons_embeddings_truncated.pkl'),
    ('GB', 'ParlaMint_GB_lords_embeddings_truncated.pkl'),
    ('HU', 'ParlaMint_HU_embeddings_truncated.pkl'),
    ('UA', 'ParlaMint_UA_embeddings_truncated.pkl'),
]

embeddings = []
for language, embedding_file in embedding_files:
    with open(Path('artefacts/bojan') / embedding_file, 'rb') as f:
        print(f'Loading', embedding_file)
        embeddings.append((language, pickle.load(f)))

# %% [markdown]
# ## Create embeddings dataframe

# %%
df = pd.DataFrame(columns=['id', 'language', 'embedding'])
for language, lang_embs in embeddings:
    df = pd.concat([df, pd.DataFrame([
        (eid, language, embedding)
        for eid, embedding in lang_embs.items()
    ], columns=['id', 'language', 'embedding'])])
df.reset_index().to_feather(artefacts / 'embeddings.feather')

# %% [markdown]
# ## Create ParlaMint dataframe

# %%
def worker(args):
    language, xml_file = args
    with open(xml_file, 'r') as f:
        soup = BeautifulSoup(f.read(), 'xml')
    sentences = []
    for speech in soup.find_all('u'):
        speech_id = speech['xml:id']
        for sentence in speech.find_all('s'):
            sentence_id = sentence['xml:id']
            sentence_text = ''
            lemmas = {}
            for unit in sentence.find_all(['w', 'pc']):
                text = unit.get_text()
                if not text:
                    continue
                if unit.name == 'w':
                    sentence_text += ' ' + unit.get_text()
                    lemma = unit.get('lemma')
                    if lemma and lemma.isalpha():
                        lemmas[lemma] = lemmas.get(lemma, 0) + 1
                elif unit.name == 'pc':
                    sentence_text += unit.get_text()
            sentence_text = sentence_text.strip()
            sentences.append([
                sentence_id,
                speech_id,
                language,
                sentence_text,
                json.dumps(lemmas)
            ])
    return sentences


def get_xml_sentences(parlamints):
    all_sentences = []

    with mp.Pool(mp.cpu_count()) as pool:
        for parlamint in parlamints:
            parlamint = [(i['language'], i['xml_path']) for i in parlamint]
            for result in tqdm(pool.imap(worker, parlamint), total=len(parlamint)):
                all_sentences.extend(result)

    return all_sentences


all_sentences = get_xml_sentences(parlamints)
df = pd.DataFrame(all_sentences, columns=['sentence_id', 'speech_id', 'language', 'text', 'lemmas_tf'])
df.to_feather(artefacts / 'parlamint_sentences.feather')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 302/302 [01:55<00:00,  2.61it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 1572/1572 [06:49<00:00,  3.84it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 2209/2209 [10:49<00:00,  3.40it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 515/515 [02:44<00:00,  3.13it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 1091/1091 [01:52<00:00,  9.70it/s]

# %%
import pandas as pd
import csv
from pathlib import Path
from multiprocessing import Pool, cpu_count
from tqdm import tqdm


def process_file(metadata):
    with open(metadata, 'r') as file:
        reader = csv.reader(file, delimiter='\t')
        columns = next(reader)
        rows = list(reader)
    return rows, columns


# get list of metadata files
files = list(Path('data/nonannotated').glob('ParlaMint-*.txt/*/ParlaMint-*meta.tsv'))

# set up a multiprocessing pool and process files in parallel
with Pool(cpu_count()) as pool:
    results = list(tqdm(pool.imap(process_file, files), total=len(files)))

# aggregate results
dataframes = [pd.DataFrame(rows, columns=columns) for rows, columns in results]
df = pd.concat(dataframes)

df.reset_index().to_feather(artefacts / 'parlamint_metadata.feather')
df
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 5689/5689 [00:07<00:00, 807.12it/s]
#                                         ID  \
# 0    ParlaMint-ES-GA_2017-09-26-DSPG040.u1
# 1    ParlaMint-ES-GA_2017-09-26-DSPG040.u2
# 2    ParlaMint-ES-GA_2017-09-26-DSPG040.u3
# 3    ParlaMint-ES-GA_2017-09-26-DSPG040.u4
# 4    ParlaMint-ES-GA_2017-09-26-DSPG040.u5
# ..                                     ...
# 213        ParlaMint-UA_2019-11-13-m0.u214
# 214        ParlaMint-UA_2019-11-13-m0.u215
# 215        ParlaMint-UA_2019-11-13-m0.u216
# 216        ParlaMint-UA_2019-11-13-m0.u217
# 217        ParlaMint-UA_2019-11-13-m0.u218
#
#                                                  Title        Date  \
# 0    Minutes of the Assembly of the Galician Parlia...  2017-09-26
# 1    Minutes of the Assembly of the Galician Parlia...  2017-09-26
# 2    Minutes of the Assembly of the Galician Parlia...  2017-09-26
# 3    Minutes of the Assembly of the Galician Parlia...  2017-09-26
# 4    Minutes of the Assembly of the Galician Parlia...  2017-09-26
# ..                                                 ...         ...
# 213  Ukrainian parliamentary corpus ParlaMint-UA, t...  2019-11-13
# 214  Ukrainian parliamentary corpus ParlaMint-UA, t...  2019-11-13
# 215  Ukrainian parliamentary corpus ParlaMint-UA, t...  2019-11-13
# 216  Ukrainian parliamentary corpus ParlaMint-UA, t...  2019-11-13
# 217  Ukrainian parliamentary corpus ParlaMint-UA, t...  2019-11-13
#
#               Body Term Session Meeting     Sitting Agenda  Subcorpus  \
# 0    Unicameralism  010             040  2017-09-26         Reference
# 1    Unicameralism  010             040  2017-09-26         Reference
# 2    Unicameralism  010             040  2017-09-26         Reference
# 3    Unicameralism  010             040  2017-09-26         Reference
# 4    Unicameralism  010             040  2017-09-26         Reference
# ..             ...  ...     ...     ...         ...    ...        ...
# 213  Unicameralism    9       2          2019-11-13         Reference
# 214  Unicameralism    9       2          2019-11-13         Reference
# 215  Unicameralism    9       2          2019-11-13         Reference
# 216  Unicameralism    9       2          2019-11-13         Reference
# 217  Unicameralism    9       2          2019-11-13         Reference
#
#     Speaker_role Speaker_MP Speaker_Minister Speaker_party  \
# 0    Chairperson         MP                -         PPdeG
# 1    Chairperson         MP                -         PPdeG
# 2        Regular         MP                -         PPdeG
# 3    Chairperson         MP                -         PPdeG
# 4    Chairperson         MP                -         PPdeG
# ..           ...        ...              ...           ...
# 213      Regular         MP                -           фЄС
# 214  Chairperson         MP                -
# 215      Regular         MP                -           фЄС
# 216  Chairperson         MP                -
# 217  Chairperson         MP                -
#
#                                     Speaker_party_name Party_status  \
# 0                           Partido Popular de Galicia    Coalition
# 1                           Partido Popular de Galicia    Coalition
# 2                           Partido Popular de Galicia    Coalition
# 3                           Partido Popular de Galicia    Coalition
# 4                           Partido Popular de Galicia    Coalition
# ..                                                 ...          ...
# 213  Фракція політичної партії "Європейська солідар...   Opposition
# 214
# 215  Фракція політичної партії "Європейська солідар...   Opposition
# 216
# 217
#
#                         Speaker_name Speaker_gender Speaker_birth
# 0    Santalices Vieira, Miguel Ángel              M          1955
# 1    Santalices Vieira, Miguel Ángel              M          1955
# 2            Arias Rodríguez, Raquel              F          1966
# 3    Santalices Vieira, Miguel Ángel              M          1955
# 4    Santalices Vieira, Miguel Ángel              M          1955
# ..                               ...            ...           ...
# 213  Олексійович Гончаренко, Олексій              M          1980
# 214   Олександрович Разумков, Дмитро              M          1983
# 215   Володимирівна Геращенко, Ірина              F          1971
# 216   Олександрович Разумков, Дмитро              M          1983
# 217   Олександрович Разумков, Дмитро              M          1983
#
# [1365550 rows x 19 columns]

# %% [markdown]
# ## Generate speech_id to lemmas mapping

# %%
sentences = pd.read_feather('artefacts/pandas_frames/parlamint_sentences.feather')

# %%
speeches = {}
for language, sentences_by_language in tqdm(sentences.groupby('language')):
    speeches[language] = {}
    for speech_id, lemmas in sentences_by_language.groupby('speech_id'):
        speeches[language][speech_id] = set()
        for lemma_tf in lemmas.lemmas_tf:
            speeches[language][speech_id].update(json.loads(lemma_tf).keys())

for language, speeches in speeches.items():
    with open(artefacts / f'speech2lemmas_{language}.pkl', 'wb') as f:
        pickle.dump(speeches, f)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [02:15<00:00, 27.14s/it]

# %%
speeches
# Out:
# {'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u1': {'a',
#   'abrir',
#   'asistencia',
#   'benvido',
#   'bo',
#   'comprobación',
#   'de',
#   'deputación',
#   'día',
#   'e',
#   'este',
#   'favor',
#   'moi',
#   'o',
#   'permanente',
#   'por',
#   'proceder',
#   'que',
#   'secretario',
#   'sesión',
#   'señor',
#   'soneira',
#   'tajes',
#   'todo',
#   'xaneiro'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u10': {'a',
#   'abaratar',
#   'aberto',
#   'abocar',
#   'abordar',
#   'abril',
#   'absolutamente',
#   'aclarar',
#   'acoller',
#   'acordo',
#   'activo',
#   'actuar',
#   'ademais',
#   'adianto',
#   'adoptar',
#   'advertir',
#   'afortunadamente',
#   'agora',
#   'agosto',
#   'alarmante',
#   'algo',
#   'algún',
#   'alto',
#   'amosar',
#   'ano',
#   'anual',
#   'apoiar',
#   'apoio',
#   'apuntar',
#   'argumento',
#   'asegurar',
#   'asinar',
#   'así',
#   'atento',
#   'atopar',
#   'aturrullo',
#   'até',
#   'ausencia',
#   'aval',
#   'axuda',
#   'aínda',
#   'baixada',
#   'baixar',
#   'barreira',
#   'ben',
#   'beneficiar',
#   'beneficio',
#   'bng',
#   'bo',
#   'borrador',
#   'broma',
#   'bueno',
#   'calada',
#   'cambio',
#   'cando',
#   'carburante',
#   'caro',
#   'casi',
#   'caso',
#   'catro',
#   'caída',
#   'central',
#   'centrar',
#   'certo',
#   'chamar',
#   'cifra',
#   'cincar',
#   'cincuenta',
#   'coar',
#   'cobertura',
#   'combustíbel',
#   'comentario',
#   'comezar',
#   'como',
#   'comparecencia',
#   'comparecer',
#   'competencia',
#   'competitivo',
#   'comunidade',
#   'con',
#   'condicionar',
#   'consecuencia',
#   'conselleiro',
#   'consello',
#   'considerar',
#   'consumidor',
#   'contemplar',
#   'contestación',
#   'contexto',
#   'contra',
#   'contrato',
#   'convocar',
#   'conxunto',
#   'corenta',
#   'correspondente',
#   'cota',
#   'cousa',
#   'coñecer',
#   'crear',
#   'crer',
#   'crise',
#   'cuarto',
#   'cuestionar',
#   'cuestión',
#   'custo',
#   'dabondo',
#   'dar',
#   'dato',
#   'de',
#   'deber',
#   'decembro',
#   'decidir',
#   'decreto',
#   'dedo',
#   'defender',
#   'demográfico',
#   'demoledor',
#   'dende',
#   'denunciar',
#   'deputación',
#   'deputado',
#   'descarado',
#   'desdeñar',
#   'desemprego',
#   'deserto',
#   'desgraza',
#   'desmentir',
#   'destrución',
#   'desvantaxe',
#   'dicir',
#   'diferenza',
#   'difícil',
#   'digno',
#   'discrepar',
#   'discurso',
#   'distinto',
#   'diésel',
#   'doce',
#   'dous',
#   'dramático',
#   'duración',
#   'durar',
#   'día',
#   'e',
#   'económico',
#   'efectivo',
#   'el',
#   'electricidade',
#   'eléctrico',
#   'emigración',
#   'empezar',
#   'emprego',
#   'empresa',
#   'en',
#   'endebedar',
#   'entender',
#   'entre',
#   'epa',
#   'ese',
#   'esgrimir',
#   'españa',
#   'especialización',
#   'espectador',
#   'estabelecer',
#   'estación',
#   'estado',
#   'estar',
#   'este',
#   'estratéxico',
#   'estudo',
#   'eu',
#   'euro',
#   'evolución',
#   'examinar',
#   'exceso',
#   'exemplo',
#   'existir',
#   'exixir',
#   'expectativa',
#   'explicar',
#   'extraer',
#   'extraordinario',
#   'facer',
#   'falar',
#   'falso',
#   'familia',
#   'favor',
#   'febreiro',
#   'feijóo',
#   'feito',
#   'ferramenta',
#   'figura',
#   'fin',
#   'final',
#   'fiábel',
#   'formular',
#   'forte',
#   'francia',
#   'galego',
#   'galicia',
#   'galiza',
#   'gandeiro',
#   'gasolineira',
#   'gasóleo',
#   'goberno',
#   'grave',
#   'graza',
#   'grupo',
#   'haber',
#   'hoxe',
#   'impacto',
#   'importante',
#   'incertidume',
#   'indicador',
#   'indicar',
#   'industria',
#   'industrial',
#   'inferior',
#   'iniciativa',
#   'insistencia',
#   'insistir',
#   'interese',
#   'intervención',
#   'ir',
#   'iso',
#   'isto',
#   'la',
#   'leiteiro',
#   'lembrar',
#   'ler',
#   'litro',
#   'lle',
#   'loitar',
#   'luchar',
#   'lácteo',
#   'madrid',
#   'maio',
#   'man',
#   'manido',
#   'mantemento',
#   'maquillar',
#   'mecanismo',
#   'mediador',
#   'medida',
#   'medio',
#   'mellor',
#   'menor',
#   'menos',
#   'mentres',
#   'mercado',
#   'mercar',
#   'mes',
#   'mesa',
#   'mesmo',
#   'ministerio',
#   'mirar',
#   'mixto',
#   'moito',
#   'momento',
#   'municipal',
#   'máis',
#   'méndez',
#   'múltiple',
#   'nada',
#   'necesario',
#   'necesidade',
#   'nefasto',
#   'negativo',
#   'negociación',
#   'neto',
#   'nin',
#   'ningún',
#   'nome',
#   'non',
#   'normativa',
#   'nos',
#   'noso',
#   'novo',
#   'o',
#   'obrigatorio',
#   'ocasión',
#   'ocorrer',
#   'ocupación',
#   'onde',
#   'ou',
#   'outro',
#   'padrón',
#   'pagar',
#   'paquete',
#   'para',
#   'parada',
#   'parado',
#   'parecer',
#   'parlamentario',
#   'parlamento',
#   'paro',
#   'parte',
#   'partido',
#   'pasado',
#   'peninsular',
#   'peor',
#   'perder',
#   'perla',
#   'permanente',
#   'permitir',
#   'pero',
#   'persoa',
#   'petróleo',
#   'pique',
#   'plantexadas',
#   'plantexando',
#   'pleno',
#   'poboacional',
#   'poboación',
#   'poder',
#   'política',
#   'popular',
#   'por',
#   'porque',
#   'porta',
#   'porén',
#   'posicionando',
#   'posición',
#   'poñer',
#   'practicar',
#   'precario',
#   'precisamente',
#   'presidente',
#   'presión',
#   'prestación',
#   'prexuízo',
#   'prezo',
#   'problema',
#   'producir',
#   'produción',
#   'produtor',
#   'propio',
#   'provocar',
#   'práctica',
#   'próximo',
#   'punto',
#   'que',
#   'quebra',
#   'querer',
#   'radicar',
#   'razón',
#   'real',
#   'recente',
#   'reclamación',
#   'reclamar',
#   'recoñecer',
#   'referencia',
#   'refinería',
#   'reiterar',
#   'relativo',
#   'rematar',
#   'repercusión',
#   'repostar',
#   'residente',
#   'responsabilidade',
#   'resposta',
#   'resto',
#   'retención',
#   'retrotraer',
#   'rexistrar',
#   'rioja',
#   'ritmo',
#   'romeu',
#   'rotundamente',
#   'rural',
#   'réxime',
#   'saber',
#   'sacrificar',
#   'sancionador',
#   'sanción',
#   'sanitario',
#   'saír',
#   'se',
#   'secar',
#   'sector',
#   'seguir',
#   'segundo',
#   'seis',
#   'sen',
#   'sequera',
#   'ser',
#   'serie',
#   'servizo',
#   'seu',
#   'señor',
#   'si',
#   'simbólico',
#   'simple',
#   'sinalar',
#   'sinatura',
#   'sinceridade',
#   'sistema',
#   'situación',
#   'situar',
#   'sobre',
#   'sobreprodución',
#   'socialista',
#   'solicitar',
#   'solicitude',
#   'suba',
#   'subir',
#   'subscribir',
#   'suficiente',
#   'superar',
#   'só',
#   'tamén',
#   'tan',
#   'tanto',
#   'tarifa',
#   'tema',
#   'tengo',
#   'ter',
#   'todo',
#   'total',
#   'traballo',
#   'transformar',
#   'trimestre',
#   'un',
#   'unidade',
#   'urxencia',
#   'urxente',
#   'vaca',
#   'vista',
#   'voceiro',
#   'xaneiro',
#   'xeito',
#   'xente',
#   'xeración',
#   'xestión',
#   'xunta',
#   'xuvenil',
#   'á',
#   'último'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u11': {'a',
#   'agora',
#   'alternativa',
#   'de',
#   'díaz',
#   'esquerda',
#   'galego',
#   'graza',
#   'grupo',
#   'jorquera',
#   'moito',
#   'o',
#   'palabra',
#   'parlamentario',
#   'señor',
#   'ter'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u12': {'a',
#   'absoluto',
#   'acarreando',
#   'acción',
#   'acomodar',
#   'acordar',
#   'activo',
#   'acumular',
#   'ademais',
#   'afectar',
#   'agora',
#   'alcumar',
#   'alguén',
#   'algún',
#   'alonso',
#   'alternativa',
#   'alto',
#   'ano',
#   'aquí',
#   'argumentario',
#   'asalariar',
#   'asociación',
#   'así',
#   'ata',
#   'atallar',
#   'atinxir',
#   'austeridade',
#   'autonomía',
#   'aínda',
#   'bankia',
#   'basear',
#   'bastante',
#   'bbva',
#   'bng',
#   'bo',
#   'bruto',
#   'bueno',
#   'báñez',
#   'c',
#   'caber',
#   'cada',
#   'calidade',
#   'cando',
#   'cantidade',
#   'capaz',
#   'carecer',
#   'casa',
#   'case',
#   'caso',
#   'ceo',
#   'certamente',
#   'certo',
#   'chantaxe',
#   'chantaxear',
#   'cidadanía',
#   'cifra',
#   'cis',
#   'citar',
#   'clamar',
#   'claro',
#   'coalición',
#   'coincidir',
#   'colapso',
#   'combater',
#   'comezar',
#   'comité',
#   'como',
#   'comparecencia',
#   'compor',
#   'comprar',
#   'con',
#   'conclusión',
#   'consecuencia',
#   'conselleiro',
#   'consellería',
#   'consolidación',
#   'construír',
#   'conta',
#   'contabilizar',
#   'conveniente',
#   'conxunto',
#   'coñecemento',
#   'coñecer',
#   'creación',
#   'crear',
#   'crecemento',
#   'crise',
#   'crítica',
#   'cuarto',
#   'cuestión',
#   'cumprir',
#   'custa',
#   'custo',
#   'dar',
#   'dato',
#   'de',
#   'debate',
#   'deber',
#   'dedicar',
#   'defender',
#   'defensa',
#   'definitivo',
#   'demolición',
#   'dende',
#   'denunciar',
#   'deputación',
#   'dereita',
#   'desaparición',
#   'desemprego',
#   'desgranalo',
#   'desmentir',
#   'despois',
#   'destrución',
#   'dez',
#   'diante',
#   'dicir',
#   'directamente',
#   'dirimir',
#   'dispor',
#   'distinto',
#   'doente',
#   'doutrina',
#   'día',
#   'dúbida',
#   'e',
#   'económico',
#   'efectivamente',
#   'elemento',
#   'emerxencia',
#   'emprego',
#   'empresa',
#   'empresarial',
#   'en',
#   'endesa',
#   'enfermo',
#   'enmarcar',
#   'enquisa',
#   'enriba',
#   'entre',
#   'epa',
#   'escaso',
#   'escena',
#   'escoitar',
#   'ese',
#   'esquerda',
#   'estado',
#   'estar',
#   'estatal',
#   'este',
#   'estupendo',
#   'euro',
#   'europeo',
#   'exactamente',
#   'exemplo',
#   'exilio',
#   'exixir',
#   'experto',
#   'explicación',
#   'explicitase',
#   'expropiación',
#   'extremo',
#   'facer',
#   'faciana',
#   'facultativo',
#   'falar',
#   'falso',
#   'farmacéutico',
#   'favor',
#   'final',
#   'fondo',
#   'forma',
#   'forte',
#   'fundamental',
#   'fátima',
#   'galego',
#   'galicia',
#   'gilead',
#   'goberno',
#   'grande',
#   'grave',
#   'gravidade',
#   'graza',
#   'grecia',
#   'grupo',
#   'haber',
#   'hepatite',
#   'hoxe',
#   'importancia',
#   'importar',
#   'inconcibible',
#   'incorporar',
#   'indefendible',
#   'indio',
#   'inditex',
#   'industria',
#   'industrial',
#   'información',
#   'insistir',
#   'instar',
#   'interesante',
#   'interesar',
#   'interese',
#   'investimento',
#   'ir',
#   'isto',
#   'laboratorio',
#   'lamentable',
#   'lle',
#   'lobbys',
#   'logo',
#   'lugar',
#   'magno',
#   'manexar',
#   'manter',
#   'marchamo',
#   'mañá',
#   'media',
#   'medicamento',
#   'medida',
#   'mellor',
#   'membro',
#   'menor',
#   'menos',
#   'mercar',
#   'mes',
#   'mesmo',
#   'milagroso',
#   'millón',
#   'ministerio',
#   'ministro',
#   'minuto',
#   'modelo',
#   'molécula',
#   'mozo',
#   'mundial',
#   'mundo',
#   'máis',
#   'méndez',
#   'nada',
#   'negativo',
#   'nin',
#   'nomear',
#   'non',
#   'nos',
#   'noso',
#   'novo',
#   'nunca',
#   'o',
#   'obter',
#   'ocasión',
#   'onte',
#   'opacidade',
#   'organización',
#   'ou',
#   'outorgar',
#   'outro',
#   'paliar',
#   'para',
#   'parada',
#   'parado',
#   'parlamentario',
#   'paro',
#   'parte',
#   'partido',
#   'pasar',
#   'patente',
#   'país',
#   'pedir',
#   'pensar',
#   'percibir',
#   'perder',
#   'permanente',
#   'pero',
#   'persoa',
#   'petición',
#   'pleno',
#   'poboación',
#   'pobreza',
#   'poder',
#   'pois',
#   'política',
#   'popular',
#   'por',
#   'porque',
#   'posta',
#   'pouco',
#   'poñer',
#   'practicar',
#   'precarización',
#   'presencial',
#   'preservar',
#   'presidente',
#   'prezo',
#   'primeiro',
#   'problema',
#   'produción',
#   'produto',
#   'profundo',
#   'propio',
#   'protocolo',
#   'pílula',
#   'público',
#   'que',
#   'quen',
#   'querer',
#   'rapidamente',
#   'razón',
#   'real',
#   'recoller',
#   'reflectir',
#   'relación',
#   'relato',
#   'relevancia',
#   'relevante',
#   'render',
#   'rendibilizar',
#   'representante',
#   'respecto',
#   'resultado',
#   'revelar',
#   'rigor',
#   'rubricar',
#   'sabelo',
#   'saber',
#   'sanidade',
#   'sanitario',
#   'saudar',
#   'saúde',
#   'saúdo',
#   'se',
#   'seguir',
#   'segundo',
#   'seguramente',
#   'semellar',
#   'sen',
#   'senón',
#   'sequera',
#   'ser',
#   'seu',
#   'señor',
#   'si',
#   'sinalar',
#   'situación',
#   'situar',
#   'soamente',
#   'sobre',
#   'social',
#   'socialista',
#   'sociolaboral',
#   'solicitude',
#   'solventar',
#   'someter',
#   'subministrar',
#   'substancial',
#   'suceder',
#   'supor',
#   'suposto',
#   'supoñer',
#   'syriza',
#   'só',
#   'tal',
#   'tamén',
#   'tan',
#   'tanto',
#   'taxa',
#   'tema',
#   'tempo',
#   'temática',
#   'ter',
#   'terrible',
#   'todo',
#   'total',
#   'traballo',
#   'tratamento',
#   'tratar',
#   'través',
#   'tremendo',
#   'trimestre',
#   'tristura',
#   'un',
#   'unión',
#   'urxencia',
#   'vacación',
#   'vencellado',
#   'vencello',
#   'ver',
#   'verbo',
#   'vicepresidente',
#   'vivir',
#   'volver',
#   'vostede',
#   'votar',
#   'xa',
#   'xaneiro',
#   'xaque',
#   'xustamente',
#   'á',
#   'éxito',
#   'último',
#   'único'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u13': {'favor', 'por', 'rematar'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u14': {'ambiental',
#   'carburante',
#   'cidade',
#   'citar',
#   'como',
#   'con',
#   'conxunto',
#   'coruña',
#   'cuestión',
#   'céntimo',
#   'de',
#   'devolver',
#   'día',
#   'e',
#   'efectivamente',
#   'efecto',
#   'elemento',
#   'elevado',
#   'estado',
#   'estar',
#   'exixir',
#   'hoxe',
#   'instar',
#   'máis',
#   'o',
#   'partido',
#   'pero',
#   'popular',
#   'presidente',
#   'prezo',
#   'propio',
#   'que',
#   'quedar',
#   'recibir',
#   'reclamar',
#   'refinería',
#   'rematar',
#   'respecto',
#   'sanitario',
#   'sen',
#   'ser',
#   'señor',
#   'substancial',
#   'só',
#   'tan',
#   'ter',
#   'todo',
#   'transportista',
#   'un',
#   'ver',
#   'xa',
#   'último'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u15': {'díaz', 'remate', 'señor'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u16': {'a',
#   'absolutamente',
#   'conselleiro',
#   'debaixo',
#   'dicir',
#   'e',
#   'escoitar',
#   'estar',
#   'facer',
#   'favor',
#   'final',
#   'leite',
#   'lácteo',
#   'nada',
#   'non',
#   'nos',
#   'noso',
#   'novamente',
#   'o',
#   'paquete',
#   'pasar',
#   'país',
#   'pensar',
#   'por',
#   'porque',
#   'prezo',
#   'produción',
#   'que',
#   'rematar',
#   'respecto',
#   'ser',
#   'ter',
#   'vender'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u17': {'díaz',
#   'graza',
#   'grupo',
#   'moito',
#   'o',
#   'palabra',
#   'parlamentario',
#   'popular',
#   'puy',
#   'señor',
#   'ter'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u18': {'a',
#   'abordar',
#   'acabar',
#   'acceso',
#   'acción',
#   'aceptar',
#   'acordo',
#   'actuar',
#   'ademais',
#   'administración',
#   'afectar',
#   'afortunadamente',
#   'agardar',
#   'age',
#   'agochar',
#   'agora',
#   'agrario',
#   'agropecuario',
#   'algo',
#   'algún',
#   'ampliación',
#   'ano',
#   'ante',
#   'anterior',
#   'antes',
#   'antivirais',
#   'apertura',
#   'aplicar',
#   'aprobar',
#   'aproveitar',
#   'aproximadamente',
#   'aquí',
#   'asturias',
#   'asumir',
#   'asunto',
#   'así',
#   'atención',
#   'atender',
#   'autonómico',
#   'axeitado',
#   'aí',
#   'aínda',
#   'baixar',
#   'banco',
#   'barco',
#   'ben',
#   'bloque',
#   'c',
#   'cal',
#   'calefacción',
#   'candidato',
#   'cando',
#   'canto',
#   'capacidade',
#   'carácter',
#   'caso',
#   'catro',
#   'celebrar',
#   'cen',
#   'cento',
#   'central',
#   'cepa',
#   'certo',
#   'chamar',
#   'chuac',
#   'cidade',
#   'circular',
#   'claramente',
#   'claro',
#   'clínico',
#   'combustible',
#   'comentario',
#   'como',
#   'comparecencia',
#   'comparecer',
#   'competencia',
#   'comportar',
#   'compromiso',
#   'con',
#   'concertar',
#   'concretamente',
#   'conlevaron',
#   'consciente',
#   'consecuencia',
#   'conselleiro',
#   'consello',
#   'conservación',
#   'considerar',
#   'constitución',
#   'construción',
#   'contestar',
#   'contorno',
#   'contratación',
#   'contrato',
#   'contribuír',
#   'control',
#   'conveniente',
#   'convocar',
#   'convocatoria',
#   'convocatorio',
#   'conxunto',
#   'corenta',
#   'corrixir',
#   'cousa',
#   'crear',
#   'crecemento',
#   'criterio',
#   'crédito',
#   'cuestión',
#   'culminar',
#   'cultura',
#   'cumprimento',
#   'cumprir',
#   'custo',
#   'cámara',
#   'céntimo',
#   'dar',
#   'dato',
#   'de',
#   'debate',
#   'debater',
#   'deber',
#   'decembro',
#   'decisión',
#   'deixar',
#   'demais',
#   'democracia',
#   'democrático',
#   'deputación',
#   'desculpa',
#   'desde',
#   'despois',
#   'determinar',
#   'devolución',
#   'diario',
#   'dicir',
#   'diferente',
#   'diferenza',
#   'director',
#   'dispositivo',
#   'dispoñible',
#   'distinto',
#   'diálogo',
#   'dotación',
#   'dous',
#   'doutrina',
#   'duración',
#   'día',
#   'e',
#   'económico',
#   'educación',
#   'elección',
#   'empoderalos',
#   'empoderar',
#   'emprego',
#   'en',
#   'encabezar',
#   'encargar',
#   'enfermo',
#   'enterou',
#   'entrar',
#   'entre',
#   'epa',
#   'equidade',
#   'ese',
#   'esforzo',
#   'españa',
#   'español',
#   'especial',
#   'esperar',
#   'estabilidade',
#   'estado',
#   'estar',
#   'estatal',
#   'este',
#   'estear',
#   'estimar',
#   'estritamente',
#   'etapa',
#   'eu',
#   'euro',
#   'europeo',
#   'evidente',
#   'evolución',
#   'exclusivamente',
#   'exemplo',
#   'exención',
#   'exercer',
#   'explicar',
#   'exportación',
#   'extraordinario',
#   'facer',
#   'falar',
#   'falta',
#   'favor',
#   'favorecer',
#   'figurar',
#   'final',
#   'financiamento',
#   'firme',
#   'fiscal',
#   'fogar',
#   'fomentar',
#   'fondo',
#   'formación',
#   'fortalecer',
#   'funcionar',
#   'función',
#   'galego',
#   'galicia',
#   'gandeiro',
#   'garantir',
#   'gasolineira',
#   'gasóleo',
#   'gobernar',
#   'goberno',
#   'grande',
#   'gripal',
#   'grupo',
#   'gustar',
#   'haber',
#   'habitual',
#   'hepatite',
#   'hidrocarburo',
#   'homoxeneidade',
#   'hospital',
#   'hospitalario',
#   'igual',
#   'implicar',
#   'importante',
#   'imposto',
#   'incidencia',
#   'incluso',
#   'inconveniente',
#   'información',
#   'informar',
#   'informe',
#   'iniciativa',
#   'innegable',
#   'inquedanza',
#   'insistir',
#   'inspección',
#   'instrumental',
#   'instrumento',
#   'intensidade',
#   'intenso',
#   'interese',
#   'interpelar',
#   'introdución',
#   'investimento',
#   'investir',
#   'ir',
#   'iso',
#   'isto',
#   'lei',
#   'levar',
#   'licenza',
#   'lingüístico',
#   'liña',
#   'lle',
#   'local',
#   'longo',
#   'lonxe',
#   'loxicamente',
#   'lugar',
#   'lugo',
#   'lácteo',
#   'maior',
#   'mañá',
#   'me',
#   'media',
#   'medicación',
#   'medida',
#   'medio',
#   'mellor',
#   'mellorar',
#   'menos',
#   'mesa',
#   'mesmo',
#   'metade',
#   'meu',
#   'mil',
#   'millón',
#   'min',
#   'modelo',
#   'moi',
#   'momento',
#   'mundo',
#   'máis',
#   'natureza',
#   'necesario',
#   'negociación',
#   'nin',
#   'ningún',
#   'non',
#   'normalidade',
#   'noroeste',
#   'nos',
#   'novo',
#   'noxo',
#   'nós',
#   'o',
#   'obradoiro',
#   'observatorio',
#   'oficial',
#   'ollar',
#   'once',
#   'oportuno',
#   'oposición',
#   'optimista',
#   'ordinario',
#   'organización',
#   'orzamento',
#   'ou',
#   'outro',
#   'pac',
#   'paciente',
#   'paquete',
#   'para',
#   'parado',
#   'parecer',
#   'parlamentario',
#   'paro',
#   'parte',
#   'particular',
#   'partido',
#   'pasividade',
#   'patronal',
#   'país',
#   'pedir',
#   'pensar',
#   'percepción',
#   'perfectamente',
#   'perla',
#   'permanente',
#   'permitir',
#   'pero',
#   'persoa',
#   'período',
#   'pesca',
#   'petición',
#   'pib',
#   'pico',
#   'pioneira',
#   'plantexaban',
#   'pleno',
#   'poder',
#   'pois',
#   'política',
#   'político',
#   'popular',
#   'por',
#   'porque',
#   'portavoz',
#   'posible',
#   'posto',
#   'pouco',
#   'practicamente',
#   'prazo',
#   'precisamente',
#   'precisar',
#   'precisión',
#   'pregunta',
#   'prensa',
#   'preocupación',
#   'presentar',
#   'presidencia',
#   'presidente',
#   'presunción',
#   'prever',
#   'prezo',
#   'primario',
#   'primeiro',
#   'privado',
#   'probable',
#   'problema',
#   'procedemento',
#   'proceso',
#   'produción',
#   'profesional',
#   'programar',
#   'propio',
#   'proposta',
#   'práctico',
#   'publicar',
#   'publicitar',
#   'público',
#   'que',
#   'quedar',
#   'querer',
#   'razoable',
#   'real',
#   'rebaixa',
#   'recibir',
#   'reclamar',
#   'recordar',
#   'recoñecer',
#   'recuperar',
#   'relacionar',
#   'relación',
#   'relevante',
#   'renda',
#   'representativo',
#   'resolución',
#   'respectable',
#   'respecto',
#   'responsable',
#   'resultar',
#   'reunión',
#   'ronsel',
#   'saber',
#   'salientable',
#   'sanidade',
#   'sanitario',
#   'saúde',
#   'se',
#   'secretario',
#   'sector',
#   'segundo',
#   'seguro',
#   'semana',
#   'semellante',
#   'sen',
#   'sentenza',
#   'senón',
#   'ser',
#   'servizo',
#   'sesión',
#   'sete',
#   'seu',
#   'señor',
#   'señoría',
#   'si',
#   'simple',
#   'sindicato',
#   'sobre',
#   'sobreprodución',
#   'social',
#   'socialista',
#   'soprar',
#   'sorprendente',
#   'subscribir',
#   'superar',
#   'suposto',
#   'sustentar',
#   'só',
#   'tampouco',
#   'tamén',
#   'tanto',
#   'taxa',
#   'tema',
#   'tempo',
#   'ter',
#   'todo',
#   'tomar',
#   'total',
#   'totalidade',
#   'traballar',
#   'traballo',
#   'tractor',
#   'tramo',
#   'transmitir',
#   'transportista',
#   'trastorno',
#   'tratamento',
#   'tratar',
#   'tributo',
#   'trimestre',
#   'turismo',
#   'técnico',
#   'un',
#   'unión',
#   'urxencia',
#   'urxente',
#   'usuario',
#   'utilizar',
#   'vacación',
#   'variar',
#   'velar',
#   'vento',
#   'ver',
#   'vigo',
#   'vir',
#   'virulencia',
#   'virus',
#   'vostede',
#   'xa',
#   'xaneiro',
#   'xeito',
#   'xeración',
#   'xeral',
#   'xerar',
#   'xestión',
#   'xunta',
#   'xustiza',
#   'xusto',
#   'á',
#   'época',
#   'órgano',
#   'último'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u19': {'favor', 'ir', 'por', 'rematar'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u2': {'abad',
#   'abeijón',
#   'agustín',
#   'alberto',
#   'alfonso',
#   'ana',
#   'antón',
#   'aria',
#   'baamonde',
#   'balseiro',
#   'beira',
#   'belén',
#   'broz',
#   'burgo',
#   'calvar',
#   'carlos',
#   'carmen',
#   'caselas',
#   'castiñeira',
#   'concepción',
#   'consuelo',
#   'cristina',
#   'díaz',
#   'e',
#   'estar',
#   'feijóo',
#   'fernández',
#   'filgueira',
#   'fraga',
#   'francisco',
#   'freire',
#   'gallego',
#   'garcía',
#   'gonzález',
#   'haber',
#   'isabel',
#   'jaime',
#   'jesús',
#   'jorquera',
#   'josé',
#   'juan',
#   'luis',
#   'lópez',
#   'manuel',
#   'marta',
#   'martínez',
#   'maría',
#   'mesa',
#   'miguel',
#   'mondelo',
#   'méndez',
#   'núñez',
#   'o',
#   'orol',
#   'pacer',
#   'pardo',
#   'paula',
#   'pedro',
#   'pontón',
#   'por',
#   'prado',
#   'presente',
#   'presidente',
#   'puy',
#   'pérez',
#   'quórum',
#   'rodríguez',
#   'romero',
#   'romeu',
#   'román',
#   'rueda',
#   'río',
#   'santiago',
#   'santín',
#   'señor',
#   'si',
#   'substituír',
#   'sánchez',
#   'tellar',
#   'torrar',
#   'valenzuela',
#   'vázquez',
#   'xesús',
#   'xosé',
#   'yolanda',
#   'ángel'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u20': {'a',
#   'aceptar',
#   'agochar',
#   'algo',
#   'ben',
#   'comparecencia',
#   'comparecer',
#   'conselleiro',
#   'convocar',
#   'de',
#   'dicir',
#   'dispor',
#   'e',
#   'estar',
#   'falar',
#   'graza',
#   'insistir',
#   'levar',
#   'mañá',
#   'moito',
#   'non',
#   'nós',
#   'o',
#   'para',
#   'pedir',
#   'petición',
#   'pleno',
#   'pois',
#   'presidente',
#   'que',
#   'querer',
#   'sanidade',
#   'se',
#   'semana',
#   'un',
#   'varios',
#   'vez',
#   'vostede'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u21': {'de',
#   'graza',
#   'moito',
#   'méndez',
#   'peche',
#   'puy',
#   'roldar',
#   'señor'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u22': {'a',
#   'aberto',
#   'acabar',
#   'aceptación',
#   'aceptar',
#   'actividade',
#   'actuación',
#   'actuar',
#   'ademais',
#   'agradecer',
#   'algo',
#   'algún',
#   'ano',
#   'análise',
#   'aprobar',
#   'aquí',
#   'aseguramento',
#   'asistencia',
#   'así',
#   'atención',
#   'autocompracencia',
#   'avanzar',
#   'baixa',
#   'baixo',
#   'bo',
#   'cambio',
#   'cando',
#   'caro',
#   'catro',
#   'chegar',
#   'claro',
#   'como',
#   'comparecencia',
#   'comunicante',
#   'con',
#   'consecuencia',
#   'considerar',
#   'conta',
#   'contra',
#   'control',
#   'corenta',
#   'corrixir',
#   'crecemento',
#   'céntimo',
#   'dar',
#   'dato',
#   'de',
#   'debater',
#   'decreto',
#   'defensor',
#   'definitivo',
#   'democrático',
#   'dende',
#   'denunciar',
#   'devolución',
#   'dicir',
#   'diferencial',
#   'diferenza',
#   'discriminar',
#   'discutir',
#   'doente',
#   'doenza',
#   'drenar',
#   'día',
#   'e',
#   'elixir',
#   'empresa',
#   'en',
#   'engadir',
#   'epa',
#   'escrutinio',
#   'ese',
#   'españa',
#   'español',
#   'establecer',
#   'estar',
#   'estatal',
#   'estatístico',
#   'este',
#   'eu',
#   'euro',
#   'europa',
#   'europeo',
#   'exactamente',
#   'exclusivamente',
#   'existir',
#   'explicación',
#   'explicar',
#   'facer',
#   'forma',
#   'friamente',
#   'futuro',
#   'fuxir',
#   'galego',
#   'galicia',
#   'galo',
#   'gandeiro',
#   'goberno',
#   'gratia',
#   'gripe',
#   'grupo',
#   'haber',
#   'hepatite',
#   'histórico',
#   'indicativo',
#   'indiscutible',
#   'inevitable',
#   'insistir',
#   'interesar',
#   'interese',
#   'inutilmente',
#   'inverso',
#   'investimento',
#   'investir',
#   'ir',
#   'isto',
#   'labor',
#   'lamentar',
#   'leite',
#   'levar',
#   'lexislatura',
#   'lle',
#   'logo',
#   'loxicamente',
#   'lugar',
#   'lácteo',
#   'madrid',
#   'maioritario',
#   'malfadado',
#   'malo',
#   'marco',
#   'mañá',
#   'media',
#   'medio',
#   'medrar',
#   'mellorar',
#   'menos',
#   'menosprezo',
#   'mes',
#   'millón',
#   'mirar',
#   'moi',
#   'moito',
#   'morto',
#   'máis',
#   'nada',
#   'necesitar',
#   'negociación',
#   'ningún',
#   'non',
#   'nos',
#   'novo',
#   'o',
#   'obriga',
#   'ocupado',
#   'ofrecer',
#   'opacidade',
#   'oposición',
#   'ou',
#   'paquete',
#   'para',
#   'parlamento',
#   'patronal',
#   'peor',
#   'pequeno',
#   'percibir',
#   'pero',
#   'plantexamos',
#   'poder',
#   'porque',
#   'posible',
#   'practicamente',
#   'prazo',
#   'precisamente',
#   'precisión',
#   'presidente',
#   'prezo',
#   'primeiro',
#   'priori',
#   'privado',
#   'problema',
#   'procurar',
#   'producir',
#   'prognóstico',
#   'propaganda',
#   'propagar',
#   'propor',
#   'proposta',
#   'propoñente',
#   'publicar',
#   'publicidade',
#   'punto',
#   'puntualización',
#   'puy',
#   'pé',
#   'póliza',
#   'público',
#   'que',
#   'querer',
#   'realidade',
#   'reclamar',
#   'remitir',
#   'render',
#   'resultado',
#   'rexeitar',
#   'rumbo',
#   'sanidade',
#   'sanitario',
#   'se',
#   'sector',
#   'seguir',
#   'segundo',
#   'seis',
#   'semana',
#   'sempre',
#   'sensibilidade',
#   'ser',
#   'serio',
#   'señor',
#   'señoría',
#   'si',
#   'sistema',
#   'sistemático',
#   'situación',
#   'sobre',
#   'sucesivamente',
#   'só',
#   'tan',
#   'tanto',
#   'taxa',
#   'tema',
#   'tempo',
#   'tendencia',
#   'tentar',
#   'ter',
#   'todo',
#   'traer',
#   'transcorrer',
#   'transportista',
#   'tres',
#   'triplo',
#   'un',
#   'vaso',
#   'verbi',
#   'vez',
#   'vostede',
#   'xa',
#   'á',
#   'último',
#   'único'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u23': {'adoptar',
#   'alternativa',
#   'bloque',
#   'centro',
#   'colapso',
#   'comparecencia',
#   'convocatoria',
#   'de',
#   'deputación',
#   'e',
#   'esquerda',
#   'extraordinario',
#   'galego',
#   'galicia',
#   'gg',
#   'graza',
#   'hospitalario',
#   'informar',
#   'ir',
#   'medida',
#   'moito',
#   'méndez',
#   'nacionalista',
#   'o',
#   'para',
#   'permanente',
#   'pleno',
#   'presidente',
#   'proceder',
#   'público',
#   'que',
#   'reunión',
#   'romeu',
#   'se',
#   'servizo',
#   'señor',
#   'situación',
#   'solicitude',
#   'urxencia',
#   'urxente',
#   'xunta'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u24': {'a',
#   'alternativa',
#   'bloque',
#   'comezar',
#   'comparecencia',
#   'con',
#   'convocatoria',
#   'de',
#   'debater',
#   'e',
#   'en',
#   'esquerda',
#   'extraordinario',
#   'galego',
#   'grupo',
#   'jorquera',
#   'lugar',
#   'nacionalista',
#   'o',
#   'palabra',
#   'para',
#   'parlamentario',
#   'parte',
#   'pasar',
#   'pleno',
#   'por',
#   'presidente',
#   'primeiro',
#   'propoñente',
#   'punto',
#   'que',
#   'repartir',
#   'representante',
#   'rolda',
#   'segundo',
#   'ser',
#   'señor',
#   'solicitude',
#   'tempo',
#   'ter',
#   'xunta'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u25': {'a',
#   'abondar',
#   'acabar',
#   'actividade',
#   'acudir',
#   'ademais',
#   'adoptar',
#   'age',
#   'algún',
#   'alto',
#   'amorear',
#   'antes',
#   'apósito',
#   'asistencial',
#   'asumir',
#   'atender',
#   'até',
#   'aumentar',
#   'avisar',
#   'aínda',
#   'banda',
#   'bandeira',
#   'beneficiario',
#   'bloquear',
#   'bng',
#   'bo',
#   'botar',
#   'boxe',
#   'bueno',
#   'básico',
#   'cadeira',
#   'calidade',
#   'cama',
#   'cando',
#   'cheo',
#   'chover',
#   'citar',
#   'colapso',
#   'coma',
#   'cometer',
#   'como',
#   'comparecencia',
#   'comparecer',
#   'con',
#   'condición',
#   'confort',
#   'conselleiro',
#   'considerar',
#   'conta',
#   'convencer',
#   'corredor',
#   'corrupción',
#   'crer',
#   'crise',
#   'cubrir',
#   'culpa',
#   'dar',
#   'data',
#   'de',
#   'debate',
#   'deber',
#   'decembro',
#   'decidir',
#   'decisión',
#   'definitivo',
#   'democrático',
#   'denunciar',
#   'dereito',
#   'desculpa',
#   'desenvolver',
#   'dicir',
#   'diferenza',
#   'dignidade',
#   'doente',
#   'dous',
#   'e',
#   'elemental',
#   'empresa',
#   'en',
#   'entender',
#   'erro',
#   'escandaloso',
#   'escaseza',
#   'escándalo',
#   'ese',
#   'espera',
#   'esperar',
#   'estar',
#   'este',
#   'estrés',
#   'explicación',
#   'explicar',
#   'facer',
#   'facultativo',
#   'falar',
#   'faltar',
#   'favor',
#   'feijóo',
#   'fin',
#   'funcionar',
#   'galego',
#   'goberno',
#   'graza',
#   'gripe',
#   'grupo',
#   'haber',
#   'hora',
#   'hoxe',
#   'importante',
#   'impulso',
#   'inaceptábel',
#   'inadecuado',
#   'indisciplinado',
#   'informar',
#   'ingresar',
#   'insistir',
#   'insultar',
#   'intimidade',
#   'ir',
#   'isto',
#   'maleducar',
#   'mantela',
#   'manter',
#   'marabilla',
#   'materia',
#   'material',
#   'mañá',
#   'medida',
#   'mes',
#   'mesmo',
#   'mesturar',
#   'meu',
#   'moito',
#   'morno',
#   'mosquera',
#   'motivo',
#   'máis',
#   'máscara',
#   'máxime',
#   'máximo',
#   'médico',
#   'nada',
#   'nebulizadoras',
#   'necesario',
#   'necesidade',
#   'negar',
#   'nin',
#   'nivel',
#   'non',
#   'nós',
#   'número',
#   'o',
#   'onde',
#   'ordenación',
#   'ou',
#   'outro',
#   'padiola',
#   'para',
#   'paso',
#   'patoloxía',
#   'pechar',
#   'pedir',
#   'persoal',
#   'pesar',
#   'planta',
#   'pleno',
#   'política',
#   'popular',
#   'por',
#   'porque',
#   'precisamente',
#   'presidente',
#   'presión',
#   'presunto',
#   'preto',
#   'primeiro',
#   'privado',
#   'problema',
#   'profesional',
#   'propio',
#   'pé',
#   'público',
#   'que',
#   'quince',
#   'racional',
#   'razón',
#   'recibir',
#   'recorte',
#   'reiterar',
#   'reposición',
#   'responsabilidade',
#   'rexistrar',
#   'risco',
#   'rocío',
#   'sala',
#   'sanidade',
#   'sanitario',
#   'se',
#   'segundo',
#   'seis',
#   'semana',
#   'sempre',
#   'sen',
#   'ser',
#   'servizo',
#   'seu',
#   'señor',
#   'significar',
#   'simplificar',
#   'sincero',
#   'situación',
#   'sobrecarga',
#   'socialista',
#   'solicitar',
#   'solicitude',
#   'subir',
#   'sufrir',
#   'suposto',
#   'só',
#   'tamén',
#   'tan',
#   'tanto',
#   'taxa',
#   'ter',
#   'textual',
#   'todo',
#   'traballo',
#   'tres',
#   'trescentas',
#   'un',
#   'urxencia',
#   'usuario',
#   'vacinar',
#   'vampirizan',
#   'ver',
#   'vergoñento',
#   'vivir',
#   'votación',
#   'votar',
#   'vulnerar',
#   'xaneiro',
#   'xestión',
#   'xunta',
#   'á'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u26': {'a',
#   'alternativa',
#   'de',
#   'díaz',
#   'esquerda',
#   'galego',
#   'graza',
#   'jorquera',
#   'moito',
#   'o',
#   'palabra',
#   'por',
#   'señor',
#   'ter'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u27': {'a',
#   'abaixo',
#   'abente',
#   'absolutamente',
#   'absoluto',
#   'acadar',
#   'acomodar',
#   'ademais',
#   'adianto',
#   'aforro',
#   'agora',
#   'alcance',
#   'algún',
#   'amigo',
#   'antes',
#   'aquilo',
#   'aquí',
#   'arranque',
#   'arredor',
#   'atención',
#   'atender',
#   'aínda',
#   'ben',
#   'beneficio',
#   'bipartito',
#   'bo',
#   'ca',
#   'cada',
#   'cadrado',
#   'cal',
#   'calidade',
#   'calquera',
#   'cama',
#   'camiseta',
#   'cando',
#   'capaz',
#   'catro',
#   'causa',
#   'centro',
#   'chuac',
#   'cidade',
#   'cidadán',
#   'cola',
#   'colapsar',
#   'comarca',
#   'como',
#   'comprender',
#   'con',
#   'conselleiro',
#   'construír',
#   'consulta',
#   'consumar',
#   'contumaz',
#   'conveniando',
#   'conveniente',
#   'convenio',
#   'conxunto',
#   'coruña',
#   'dar',
#   'dato',
#   'de',
#   'demais',
#   'dende',
#   'derivar',
#   'desigualdade',
#   'diante',
#   'dicir',
#   'disparar',
#   'dous',
#   'duplo',
#   'durante',
#   'día',
#   'dúbida',
#   'e',
#   'efectivamente',
#   'el',
#   'empeñar',
#   'en',
#   'ese',
#   'espera',
#   'estado',
#   'estar',
#   'estatal',
#   'estrutural',
#   'eu',
#   'euro',
#   'exactamente',
#   'exemplo',
#   'exercer',
#   'explicitara',
#   'extremo',
#   'facer',
#   'facultativo',
#   'falar',
#   'ferrol',
#   'formulación',
#   'forzoso',
#   'foto',
#   'fracaso',
#   'fóra',
#   'galego',
#   'galicia',
#   'garantía',
#   'gardar',
#   'gasto',
#   'gobernar',
#   'goberno',
#   'grave',
#   'graza',
#   'gripe',
#   'groso',
#   'gustar',
#   'haber',
#   'hora',
#   'horario',
#   'hospital',
#   'hoxe',
#   'humano',
#   'ideolóxico',
#   'igual',
#   'imposible',
#   'inaugurar',
#   'indecente',
#   'inexplicable',
#   'insistir',
#   'instalación',
#   'inverno',
#   'ir',
#   'iso',
#   'isto',
#   'jorquera',
#   'lago',
#   'lei',
#   'lista',
#   'lonxe',
#   'lugar',
#   'magnífico',
#   'man',
#   'maneira',
#   'manter',
#   'material',
#   'materializar',
#   'media',
#   'medida',
#   'medio',
#   'mellor',
#   'menos',
#   'mesmo',
#   'metro',
#   'mil',
#   'millón',
#   'mirar',
#   'modelo',
#   'moi',
#   'mor',
#   'máis',
#   'máximo',
#   'nada',
#   'nadal',
#   'naval',
#   'non',
#   'nos',
#   'noso',
#   'o',
#   'operar',
#   'orzamentario',
#   'ou',
#   'para',
#   'partido',
#   'pasar',
#   'país',
#   'pechar',
#   'peche',
#   'pedir',
#   'peor',
#   'perda',
#   'pero',
#   'persoa',
#   'persoal',
#   'pesar',
#   'planta',
#   'pleno',
#   'poder',
#   'pois',
#   'política',
#   'popular',
#   'por',
#   'porque',
#   'porta',
#   'posto',
#   'povisa',
#   'poñer',
#   'precisar',
#   'premiar',
#   'presidente',
#   'prestación',
#   'presumir',
#   'pretender',
#   'preto',
#   'privado',
#   'privatización',
#   'proba',
#   'problema',
#   'problemática',
#   'profesional',
#   'propio',
#   'puy',
#   'páxina',
#   'que',
#   'quirófano',
#   'radiolóxico',
#   'rapidamente',
#   'razón',
#   'real',
#   'recortar',
#   'recorte',
#   'rede',
#   'reflexión',
#   'relatar',
#   'rendemento',
#   'reproducir',
#   'responsable',
#   'resto',
#   'ránking',
#   'saber',
#   'sacar',
#   'sanidade',
#   'sanitario',
#   'santalices',
#   'saír',
#   'se',
#   'segredo',
#   'seguinte',
#   'seguir',
#   'segundo',
#   'sen',
#   'senón',
#   'ser',
#   'sergas',
#   'seu',
#   'señor',
#   'si',
#   'sinalar',
#   'sistema',
#   'sistemático',
#   'situación',
#   'soamente',
#   'sobre',
#   'supor',
#   'sur',
#   'só',
#   'tamén',
#   'tanto',
#   'tarde',
#   'tempada',
#   'ter',
#   'terceiro',
#   'tipo',
#   'todo',
#   'traballar',
#   'traer',
#   'transparencia',
#   'un',
#   'urxencia',
#   'variación',
#   'ver',
#   'vez',
#   'vigo',
#   'vir',
#   'vivir',
#   'vivo',
#   'voceiro',
#   'vostede',
#   'web',
#   'xa',
#   'xaque',
#   'xestionar',
#   'xiratorio',
#   'xubilación',
#   'xunta',
#   'xustamente',
#   'á',
#   'área'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u28': {'díaz',
#   'favor',
#   'por',
#   'remate',
#   'señor'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u29': {'a',
#   'ataque',
#   'colapso',
#   'como',
#   'crer',
#   'cumprido',
#   'dabondo',
#   'dar',
#   'de',
#   'dende',
#   'e',
#   'empezar',
#   'estar',
#   'evidenciar',
#   'galicia',
#   'inconveniente',
#   'jorquera',
#   'logo',
#   'mañá',
#   'máis',
#   'non',
#   'noso',
#   'o',
#   'para',
#   'partido',
#   'pasar',
#   'petición',
#   'política',
#   'popular',
#   'presidente',
#   'público',
#   'que',
#   'razón',
#   'recorte',
#   'rematar',
#   'resposta',
#   'sanidade',
#   'ser',
#   'señor',
#   'ter',
#   'todo',
#   'un',
#   'urxencia',
#   'xa',
#   'xunta',
#   'xustamente'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u3': {'a',
#   'adoptar',
#   'afrontar',
#   'alternativa',
#   'ambiente',
#   'así',
#   'ausencia',
#   'bloque',
#   'celebración',
#   'centro',
#   'colapso',
#   'combustible',
#   'comezar',
#   'como',
#   'comparecencia',
#   'competitivo',
#   'conselleiro',
#   'constar',
#   'conta',
#   'convocatoria',
#   'coñecer',
#   'crise',
#   'curación',
#   'dar',
#   'de',
#   'deputación',
#   'desemprego',
#   'desenvolvemento',
#   'desvantaxe',
#   'devandito',
#   'devolución',
#   'diante',
#   'día',
#   'e',
#   'en',
#   'enfermo',
#   'esquerda',
#   'explicar',
#   'extraordinario',
#   'galego',
#   'galicia',
#   'gg',
#   'goberno',
#   'graza',
#   'hepatite',
#   'hospital',
#   'hospitalario',
#   'informar',
#   'infraestrutura',
#   'ir',
#   'lácteo',
#   'marcha',
#   'medida',
#   'medio',
#   'moito',
#   'nacionalista',
#   'o',
#   'orde',
#   'para',
#   'permanente',
#   'persoa',
#   'pleno',
#   'pois',
#   'posición',
#   'poñer',
#   'presidente',
#   'prever',
#   'prezo',
#   'problema',
#   'proceder',
#   'profesional',
#   'punto',
#   'público',
#   'que',
#   'resposta',
#   'reunión',
#   'saber',
#   'sanidade',
#   'se',
#   'sector',
#   'servizo',
#   'señor',
#   'situación',
#   'socialista',
#   'solicitude',
#   'soneira',
#   'traba',
#   'transporte',
#   'transportista',
#   'tributo',
#   'urxencia',
#   'urxente',
#   'vostede',
#   'xunta',
#   'único'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u30': {'díaz',
#   'graza',
#   'grupo',
#   'martínez',
#   'mixto',
#   'moito',
#   'parlamentario',
#   'roldar',
#   'señor'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u31': {'a',
#   'abandonar',
#   'acabar',
#   'ademais',
#   'agora',
#   'alimentar',
#   'ambiental',
#   'ampliar',
#   'ano',
#   'anunciar',
#   'apoiar',
#   'aportar',
#   'aproveitar',
#   'atención',
#   'atender',
#   'atrever',
#   'autorización',
#   'aí',
#   'barco',
#   'ben',
#   'cadea',
#   'cama',
#   'camiño',
#   'case',
#   'casual',
#   'catro',
#   'chegar',
#   'cincar',
#   'cirúrxico',
#   'colapso',
#   'coller',
#   'comisión',
#   'como',
#   'comparecencia',
#   'complicar',
#   'con',
#   'concerto',
#   'condición',
#   'consciente',
#   'contrato',
#   'corrupción',
#   'cuestión',
#   'culpa',
#   'custo',
#   'dar',
#   'de',
#   'deber',
#   'deixar',
#   'dentro',
#   'deprimir',
#   'dereito',
#   'descanso',
#   'desde',
#   'desmantelar',
#   'despedimento',
#   'despedir',
#   'despois',
#   'deterioración',
#   'deteriorar',
#   'dicir',
#   'dous',
#   'día',
#   'e',
#   'económico',
#   'embargo',
#   'empeorar',
#   'empresario',
#   'en',
#   'encadear',
#   'encarecer',
#   'enfermidade',
#   'escravista',
#   'ese',
#   'especialista',
#   'establecer',
#   'estar',
#   'este',
#   'evidente',
#   'exemplo',
#   'explicación',
#   'explotación',
#   'explotador',
#   'expor',
#   'facer',
#   'falar',
#   'farmacolóxico',
#   'final',
#   'fogar',
#   'folga',
#   'gastar',
#   'graza',
#   'gripe',
#   'haber',
#   'hospital',
#   'hospitalario',
#   'impor',
#   'impoñer',
#   'incluír',
#   'indemnización',
#   'infección',
#   'influír',
#   'iniciativa',
#   'inmediato',
#   'inmunolóxico',
#   'intervención',
#   'introducir',
#   'ir',
#   'iso',
#   'isto',
#   'laboral',
#   'lei',
#   'levar',
#   'lle',
#   'mal',
#   'man',
#   'mandar',
#   'marcar',
#   'meixoeiro',
#   'mentres',
#   'mes',
#   'meu',
#   'min',
#   'moito',
#   'mutuo',
#   'máis',
#   'máximo',
#   'médico',
#   'mínimo',
#   'nacer',
#   'nada',
#   'nin',
#   'ningún',
#   'non',
#   'nos',
#   'o',
#   'ocorrer',
#   'onde',
#   'ou',
#   'outro',
#   'paciente',
#   'palabra',
#   'para',
#   'parte',
#   'partido',
#   'pasar',
#   'pauta',
#   'pena',
#   'peor',
#   'pequeno',
#   'permanente',
#   'pero',
#   'persoa',
#   'persoal',
#   'petición',
#   'pleno',
#   'poboación',
#   'poder',
#   'pois',
#   'política',
#   'pool',
#   'popular',
#   'por',
#   'porque',
#   'pouquiño',
#   'povisa',
#   'practicamente',
#   'presidente',
#   'prestación',
#   'primario',
#   'principio',
#   'privado',
#   'privatizadora',
#   'privatizar',
#   'problema',
#   'propio',
#   'público',
#   'que',
#   'quedar',
#   'querer',
#   'real',
#   'recorte',
#   'rehabilitación',
#   'rei',
#   'reposición',
#   'roubar',
#   'sanidade',
#   'sanitario',
#   'se',
#   'seguimento',
#   'seguir',
#   'semanal',
#   'sen',
#   'ser',
#   'sergas',
#   'servizo',
#   'seu',
#   'situación',
#   'sobre',
#   'substituír',
#   'só',
#   'tamén',
#   'tanto',
#   'tardar',
#   'taxa',
#   'ter',
#   'tipo',
#   'todo',
#   'traballador',
#   'traballar',
#   'tratamento',
#   'tratar',
#   'tres',
#   'un',
#   'urxencia',
#   'vez',
#   'vigo',
#   'vir',
#   'vivir',
#   'vostede',
#   'vía',
#   'xa',
#   'xente',
#   'xunta',
#   'á'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u32': {'a',
#   'aquí',
#   'coar',
#   'con',
#   'cordialidade',
#   'crear',
#   'de',
#   'deputación',
#   'deputado',
#   'e',
#   'entender',
#   'estar',
#   'este',
#   'eu',
#   'expresión',
#   'gallego',
#   'graza',
#   'haber',
#   'inciso',
#   'martínez',
#   'min',
#   'moito',
#   'ninguén',
#   'novo',
#   'o',
#   'palabra',
#   'permanente',
#   'período',
#   'poder',
#   'que',
#   'roubar',
#   'se',
#   'ser',
#   'señor',
#   'soamente',
#   'sobrar',
#   'ter',
#   'todo',
#   'traballar',
#   'un',
#   'utilizar',
#   'vostede'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u33': {'a',
#   'absolutamente',
#   'acabar',
#   'acadar',
#   'aceptación',
#   'achegar',
#   'actualidade',
#   'acumular',
#   'adoptar',
#   'afectar',
#   'agardar',
#   'age',
#   'alegría',
#   'almacenaxe',
#   'alta',
#   'ampliación',
#   'ano',
#   'anterior',
#   'apoiar',
#   'apoio',
#   'aprobación',
#   'arrastrar',
#   'asumir',
#   'asunción',
#   'ata',
#   'atención',
#   'ausencia',
#   'baixa',
#   'ben',
#   'bng',
#   'bo',
#   'cada',
#   'calidade',
#   'calquera',
#   'cama',
#   'campaña',
#   'cando',
#   'caos',
#   'carecer',
#   'carencia',
#   'case',
#   'caso',
#   'catro',
#   'caótico',
#   'celebrar',
#   'centro',
#   'certo',
#   'chegar',
#   'chuac',
#   'cidadanía',
#   'coar',
#   'colapsar',
#   'colapso',
#   'como',
#   'comparecencia',
#   'comportamento',
#   'con',
#   'condición',
#   'confort',
#   'consecuencia',
#   'conselleiro',
#   'continuación',
#   'contratar',
#   'contrato',
#   'corresponder',
#   'cousa',
#   'cuestión',
#   'dar',
#   'de',
#   'decisión',
#   'deixar',
#   'demais',
#   'dende',
#   'denunciar',
#   'deputado',
#   'desde',
#   'desenvolver',
#   'desmotivados',
#   'dicir',
#   'doente',
#   'dous',
#   'durante',
#   'día',
#   'e',
#   'empezar',
#   'empregado',
#   'emprego',
#   'en',
#   'encadear',
#   'enfermidade',
#   'entrega',
#   'ese',
#   'espazo',
#   'especialista',
#   'esperar',
#   'estar',
#   'este',
#   'eu',
#   'evidenciar',
#   'evidente',
#   'evitar',
#   'exemplar',
#   'exemplo',
#   'exercer',
#   'exixir',
#   'explicación',
#   'explicar',
#   'facer',
#   'falar',
#   'falla',
#   'faltar',
#   'familia',
#   'favorable',
#   'feijóo',
#   'fixo',
#   'forzar',
#   'forzoso',
#   'galego',
#   'galicia',
#   'goberno',
#   'graza',
#   'gripe',
#   'grupo',
#   'haber',
#   'hospital',
#   'hospitalario',
#   'hoxe',
#   'impedir',
#   'imposible',
#   'inasumible',
#   'incorporar',
#   'inesperado',
#   'infrahumano',
#   'insistir',
#   'inverno',
#   'ir',
#   'irresponsable',
#   'iso',
#   'levar',
#   'lexislatura',
#   'lle',
#   'logo',
#   'lugar',
#   'manifesto',
#   'masivo',
#   'mañá',
#   'media',
#   'meixoeiro',
#   'menos',
#   'mes',
#   'mesmo',
#   'metade',
#   'meu',
#   'mirar',
#   'moito',
#   'momento',
#   'mudar',
#   'máis',
#   'médico',
#   'nada',
#   'namentres',
#   'nin',
#   'ninguén',
#   'nome',
#   'non',
#   'novo',
#   'o',
#   'oferta',
#   'oitenta',
#   'onde',
#   'oposición',
#   'orzamentario',
#   'orzamento',
#   'ou',
#   'ourense',
#   'outro',
#   'paciencia',
#   'para',
#   'paradigmático',
#   'parlamentario',
#   'parlamento',
#   'parte',
#   'partido',
#   'país',
#   'peche',
#   'pedir',
#   'pequeno',
#   'perdón',
#   'pero',
#   'persoa',
#   'persoal',
#   'pesar',
#   'petición',
#   'planta',
#   'pleno',
#   'poder',
#   'pois',
#   'política',
#   'político',
#   'popular',
#   'por',
#   'porque',
#   'portavoz',
#   'posicionamento',
#   'poñer',
#   'praza',
#   'presidente',
#   'presión',
#   'prestación',
#   'prestar',
#   'primeiro',
#   'principio',
#   'problema',
#   'producir',
#   'profesional',
#   'profesionalidade',
#   'propiedade',
#   'propio',
#   'provocar',
#   'práctica',
#   'prórroga',
#   'punto',
#   'público',
#   'que',
#   'quedar',
#   'quen',
#   'querer',
#   'razón',
#   'realidade',
#   'recortar',
#   'recorte',
#   'recurso',
#   'reformar',
#   'reparar',
#   'repor',
#   'reposición',
#   'repoñer',
#   'responsabilidade',
#   'resto',
#   'resultar',
#   'retirar',
#   'retornar',
#   'rexeitar',
#   'sanidade',
#   'sanitario',
#   'se',
#   'seis',
#   'selo',
#   'senso',
#   'ser',
#   'sergas',
#   'servizo',
#   'sesión',
#   'setenta',
#   'seu',
#   'señor',
#   'simple',
#   'sistema',
#   'sistemático',
#   'situación',
#   'socialista',
#   'solicitude',
#   'substitución',
#   'substituír',
#   'sufrir',
#   'suplir',
#   'só',
#   'tal',
#   'tamén',
#   'tan',
#   'taxa',
#   'temerario',
#   'tempo',
#   'ter',
#   'todo',
#   'traballar',
#   'traballo',
#   'tratar',
#   'través',
#   'un',
#   'unicamente',
#   'universitario',
#   'urxencia',
#   'utilizar',
#   'vacación',
#   'vacante',
#   'vacina',
#   'vacinar',
#   'ver',
#   'vez',
#   'vir',
#   'vivir',
#   'voluntarismo',
#   'volver',
#   'vostede',
#   'xaneiro',
#   'xerencia',
#   'xestión',
#   'xubilación',
#   'xubilado',
#   'xubilar',
#   'xunta',
#   'á',
#   'último'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u34': {'gallego',
#   'graza',
#   'grupo',
#   'moito',
#   'o',
#   'palabra',
#   'parlamentario',
#   'popular',
#   'santalices',
#   'señor',
#   'ter'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u35': {'a',
#   'abaixo',
#   'absolutamente',
#   'acabar',
#   'acadar',
#   'aceptar',
#   'acordar',
#   'actividade',
#   'adecuado',
#   'ademais',
#   'age',
#   'agora',
#   'alarmar',
#   'alarmismo',
#   'algo',
#   'alto',
#   'analizar',
#   'andar',
#   'ante',
#   'anterior',
#   'aplicar',
#   'aprazar',
#   'aprobar',
#   'apurar',
#   'aquí',
#   'arrastrar',
#   'arreglar',
#   'aspecto',
#   'asunto',
#   'asustar',
#   'así',
#   'ata',
#   'atención',
#   'atopar',
#   'autoconcertación',
#   'autonómico',
#   'autorizar',
#   'aí',
#   'aínda',
#   'bandazo',
#   'ben',
#   'bloque',
#   'bo',
#   'bueno',
#   'cal',
#   'cama',
#   'cambio',
#   'cando',
#   'cantar',
#   'canto',
#   'case',
#   'caso',
#   'cataluña',
#   'causa',
#   'celebración',
#   'celebrar',
#   'certo',
#   'cirúrxico',
#   'claro',
#   'como',
#   'comparecencia',
#   'comparecer',
#   'compoñente',
#   'con',
#   'consecuencia',
#   'conselleiro',
#   'consellería',
#   'consello',
#   'consistir',
#   'conta',
#   'continuar',
#   'contrario',
#   'contrastar',
#   'contundencia',
#   'contundente',
#   'convencer',
#   'convencido',
#   'cousa',
#   'coñecemento',
#   'coñecer',
#   'crear',
#   'criterio',
#   'cuestión',
#   'dato',
#   'de',
#   'debate',
#   'debater',
#   'deber',
#   'dedicar',
#   'deixar',
#   'deputación',
#   'desde',
#   'desgaste',
#   'determinar',
#   'dicir',
#   'distar',
#   'dividir',
#   'domiciliario',
#   'dous',
#   'dubidar',
#   'día',
#   'e',
#   'ecuación',
#   'eh',
#   'elección',
#   'empezar',
#   'en',
#   'encantar',
#   'entender',
#   'entre',
#   'entón',
#   'erróneo',
#   'escoitar',
#   'ese',
#   'espazo',
#   'españa',
#   'espera',
#   'estar',
#   'este',
#   'estear',
#   'etapa',
#   'eu',
#   'exemplo',
#   'existir',
#   'expresión',
#   'extraordinario',
#   'facer',
#   'falar',
#   'falir',
#   'feijóo',
#   'financiamento',
#   'frecuentación',
#   'galego',
#   'garantir',
#   'gañar',
#   'goberno',
#   'graza',
#   'grecia',
#   'grupo',
#   'gustar',
#   'haber',
#   'hemeroteca',
#   'hepatite',
#   'historia',
#   'histórico',
#   'hospital',
#   'hospitalario',
#   'hospitalizar',
#   'hoxe',
#   'humano',
#   'igual',
#   'implantar',
#   'importante',
#   'incluír',
#   'indubidable',
#   'información',
#   'ingresar',
#   'ingreso',
#   'inquedanza',
#   'insistir',
#   'integrar',
#   'interesante',
#   'interese',
#   'intervención',
#   'ir',
#   'iso',
#   'isto',
#   'lista',
#   'lle',
#   'mal',
#   'man',
#   'matizar',
#   'me',
#   'medida',
#   'mediática',
#   'mellor',
#   'memoria',
#   'mencionar',
#   'mermar',
#   'meu',
#   'min',
#   'modesto',
#   'moi',
#   'moito',
#   'moitísimo',
#   'momento',
#   'mundo',
#   'máis',
#   'máximo',
#   'médico',
#   'méndez',
#   'nacional',
#   'nacionalista',
#   'nada',
#   'necesitar',
#   'ninguén',
#   'non',
#   'normal',
#   'nos',
#   'noso',
#   'nunca',
#   'o',
#   'obrigación',
#   'ocasión',
#   'ollo',
#   'onde',
#   'opinión',
#   'ou',
#   'outro',
#   'pac',
#   'paciente',
#   'para',
#   'parir',
#   'parlamentario',
#   'parlamento',
#   'pasar',
#   'pechar',
#   'pegar',
#   'pensar',
#   'peonadas',
#   'percepción',
#   'perdón',
#   'perigoso',
#   'permanente',
#   'pero',
#   'petición',
#   'plan',
#   'pleno',
#   'poboación',
#   'poder',
#   'pois',
#   'político',
#   'por',
#   'porcentaxe',
#   'porque',
#   'portavoz',
#   'pouco',
#   'poñer',
#   'presidente',
#   'presionar',
#   'presión',
#   'prestar',
#   'primario',
#   'primeiro',
#   'prioridade',
#   'problema',
#   'producir',
#   'profundo',
#   'programación',
#   'programar',
#   'proposta',
#   'protagonismo',
#   'prudencia',
#   'prudente',
#   'punto',
#   'puntual',
#   'que',
#   'querer',
#   'racional',
#   'real',
#   'recordar',
#   'recorte',
#   'recurso',
#   'relacionar',
#   'relación',
#   'rendibilidade',
#   'repasar',
#   'repercutir',
#   'repetir',
#   'representante',
#   'resolución',
#   'rifar',
#   'romeu',
#   'saber',
#   'salvo',
#   'sanidade',
#   'sanitario',
#   'saír',
#   'saúde',
#   'se',
#   'seguir',
#   'sen',
#   'senso',
#   'ser',
#   'servizo',
#   'sesión',
#   'seu',
#   'señor',
#   'si',
#   'similar',
#   'sistema',
#   'situación',
#   'soamente',
#   'sobre',
#   'suceder',
#   'suposto',
#   'suspender',
#   'suspensión',
#   'só',
#   'tampouco',
#   'tamén',
#   'tanguila',
#   'tanto',
#   'teima',
#   'tema',
#   'tempo',
#   'ter',
#   'tocar',
#   'todo',
#   'traballo',
#   'transporte',
#   'tratar',
#   'través',
#   'triaxe',
#   'ucd',
#   'un',
#   'urxencia',
#   'urxente',
#   'usuario',
#   'varios',
#   'ver',
#   'vez',
#   'vir',
#   'vostede',
#   'xa',
#   'xente',
#   'xerar',
#   'xestión',
#   'xunta',
#   'único'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u36': {'favor', 'ir', 'por', 'rematar'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u37': {'actitude',
#   'ademais',
#   'antes',
#   'aprobar',
#   'atención',
#   'c',
#   'claro',
#   'como',
#   'comparecer',
#   'con',
#   'conselleiro',
#   'cousa',
#   'crear',
#   'de',
#   'deber',
#   'dicir',
#   'e',
#   'en',
#   'falar',
#   'galego',
#   'hepatite',
#   'hospitalario',
#   'ilimitado',
#   'ir',
#   'isto',
#   'momento',
#   'non',
#   'o',
#   'onde',
#   'para',
#   'pensar',
#   'pleno',
#   'político',
#   'poñer',
#   'que',
#   'respecto',
#   'sanidade',
#   'sanitario',
#   'saúde',
#   'ser',
#   'sistema',
#   'sostibilidade',
#   'só',
#   'tamén',
#   'tanto',
#   'temblando',
#   'tempo',
#   'ter',
#   'urxencia',
#   'xeral',
#   'xestión',
#   'á'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u38': {'favor',
#   'por',
#   'rematar',
#   'santalices',
#   'señor'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u39': {'autorizar',
#   'bo',
#   'comparecencia',
#   'crear',
#   'despois',
#   'e',
#   'el',
#   'eu',
#   'falar',
#   'graza',
#   'ilimitado',
#   'información',
#   'ir',
#   'moito',
#   'máis',
#   'nada',
#   'non',
#   'nós',
#   'o',
#   'para',
#   'pedir',
#   'poder',
#   'presidente',
#   'proceder',
#   'que',
#   'señor',
#   'si',
#   'tanto',
#   'tempo',
#   'ter',
#   'un',
#   'urxencia',
#   'vostede'},
#  'ParlaMint-ES-GA_2015-01-26-DSPGDP007.u4': {'a',
#   'acumular',
#   'adecuado',
#   'ademais',
#   'afrontar',
#   'alternativa',
#   'ambiente',
#   'ambos',
#   'así',
#   'ausencia',
#   'bloque',
#   'catro',
#   'celebración',
#   'cinco',
#   'colapso',
#   'combustible',
#   'comezar',
#   'como',
#   'comparecencia',
#   'competitivo',
#   'conselleiro',
#   'conta',
#   'convocatoria',
#   'conxunto',
#   'coñecer',
#   'crise',
#   'curación',
#   'dar',
#   'de',
#   'debate',
#   'deputación',
#   'desemprego',
#   'desvantaxe',
#   'devandito',
#   'devolución',
#   'dez',
#   'diante',
#   'documento',
#   'dous',
#   'e',
#   'en',
#   'enfermo',
#   'esquerda',
#   'explicar',
#   'extraordinario',
#   'facer',
#   'galego',
#   'galicia',
#   'goberno',
#   'grupo',
#   'habitual',
#   'hepatite',
#   'hospital',
#   'infraestrutura',
#   'iniciativa',
#   'lle',
#   'lugar',
#   'lácteo',
#   'marcha',
#   'medida',
#   'medio',
# ...
#   'de',
#   'deber',
#   'definitivo',
#   'dependente',
#   'depender',
#   'desexar',
#   'deseño',
#   'desguaces',
#   'desidia',
#   'determinar',
#   'dicir',
#   'e',
#   'eliminar',
#   'emenda',
#   'empezar',
#   'en',
#   'engader',
#   'entender',
#   'esbozar',
#   'especie',
#   'esperar',
#   'establecer',
#   'estado',
#   'estar',
#   'este',
#   'estratéxico',
#   'estrutural',
#   'exemplo',
#   'existente',
#   'facer',
#   'faena',
#   'falir',
#   'falta',
#   'frota',
#   'galego',
#   'galiza',
#   'goberno',
#   'grande',
#   'grupo',
#   'haber',
#   'hoxe',
#   'ibérico',
#   'igual',
#   'importante',
#   'incentivar',
#   'iniciativa',
#   'inmediato',
#   'intentar',
#   'intre',
#   'ir',
#   'isto',
#   'medida',
#   'medio',
#   'menos',
#   'mesmo',
#   'meu',
#   'minusvaloran',
#   'moción',
#   'modificación',
#   'multa',
#   'máis',
#   'namentres',
#   'necesario',
#   'nin',
#   'ninguén',
#   'ningún',
#   'non',
#   'noso',
#   'o',
#   'obviar',
#   'ocorrer',
#   'operar',
#   'oportunidade',
#   'orientar',
#   'ou',
#   'outro',
#   'para',
#   'parche',
#   'parte',
#   'partido',
#   'pasado',
#   'peixe',
#   'penalización',
#   'perder',
#   'pero',
#   'pesca',
#   'pescar',
#   'pesqueiro',
#   'plan',
#   'poder',
#   'pois',
#   'polo',
#   'política',
#   'político',
#   'por',
#   'porque',
#   'posibilidade',
#   'posible',
#   'posición',
#   'practicamente',
#   'premuras',
#   'presentar',
#   'presente',
#   'preservar',
#   'pretender',
#   'prexudicar',
#   'prezo',
#   'primeiro',
#   'problema',
#   'proceder',
#   'propagandístico',
#   'propio',
#   'proposta',
#   'propoñente',
#   'protexer',
#   'punto',
#   'que',
#   'querer',
#   'quilo',
#   'recoller',
#   'redución',
#   'reivindicación',
#   'rendibilidade',
#   'rendible',
#   'rendíbel',
#   'resolución',
#   'restritivo',
#   'retirada',
#   'sanción',
#   'sardiña',
#   'se',
#   'segmento',
#   'sen',
#   'senón',
#   'ser',
#   'seu',
#   'sobre',
#   'socialista',
#   'solucionar',
#   'someter',
#   'suceder',
#   'só',
#   'tamén',
#   'tanto',
#   'tempo',
#   'ter',
#   'titular',
#   'todo',
#   'tonelaxe',
#   'tres',
#   'tripulante',
#   'un',
#   'urxencia',
#   'urxente',
#   'venda',
#   'vender',
#   'ver',
#   'viiib',
#   'voceiro',
#   'votar',
#   'xa',
#   'xarda',
#   'xeito',
#   'xestión',
#   'xunta',
#   'xurelo',
#   'zona',
#   'único'},
#  'ParlaMint-ES-GA_2015-02-24-DSPG098.u244': {'favor', 'ir', 'por', 'rematar'},
#  'ParlaMint-ES-GA_2015-02-24-DSPG098.u245': {'aceptar',
#   'acontecemento',
#   'actividade',
#   'cabalo',
#   'cerco',
#   'discriminar',
#   'e',
#   'emenda',
#   'en',
#   'ese',
#   'esperar',
#   'estar',
#   'este',
#   'facer',
#   'frota',
#   'graza',
#   'ir',
#   'mesmo',
#   'moito',
#   'máis',
#   'nada',
#   'ningún',
#   'non',
#   'noso',
#   'o',
#   'para',
#   'partido',
#   'pesqueiro',
#   'planificar',
#   'política',
#   'proposta',
#   'que',
#   'rematar',
#   'rendible',
#   'resumo',
#   'se',
#   'sempre',
#   'ser',
#   'sobre',
#   'socialista',
#   'un'},
#  'ParlaMint-ES-GA_2015-02-24-DSPG098.u246': {'bloque',
#   'chapela',
#   'galego',
#   'graza',
#   'grupo',
#   'moito',
#   'nacionalista',
#   'o',
#   'palabra',
#   'parlamentario',
#   'roda',
#   'señor',
#   'ter'},
#  'ParlaMint-ES-GA_2015-02-24-DSPG098.u247': {'a',
#   'acompañante',
#   'actualización',
#   'administración',
#   'afectar',
#   'agora',
#   'algo',
#   'alá',
#   'ano',
#   'aquel',
#   'aquí',
#   'armador',
#   'arrastre',
#   'arte',
#   'atrás',
#   'aí',
#   'baixo',
#   'barco',
#   'biscaíño',
#   'bng',
#   'botar',
#   'cando',
#   'captura',
#   'cerco',
#   'certo',
#   'chan',
#   'colaborar',
#   'como',
#   'comprobar',
#   'comprometer',
#   'con',
#   'consciente',
#   'conselleiro',
#   'constar',
#   'continxentadas',
#   'conxuntamente',
#   'corresponder',
#   'coruñés',
#   'criterio',
#   'daquela',
#   'data',
#   'de',
#   'decisión',
#   'defender',
#   'defensa',
#   'deixar',
#   'dende',
#   'dereito',
#   'despois',
#   'destrución',
#   'dez',
#   'dicir',
#   'directamente',
#   'drama',
#   'dramático',
#   'drástico',
#   'día',
#   'e',
#   'efectuar',
#   'en',
#   'enfrontar',
#   'esgotamento',
#   'establecer',
#   'estado',
#   'estar',
#   'este',
#   'evidenciar',
#   'exactamente',
#   'exemplo',
#   'existir',
#   'expoñer',
#   'faenar',
#   'forma',
#   'fraga',
#   'galego',
#   'galiza',
#   'goberno',
#   'gravísimo',
#   'haber',
#   'histórico',
#   'hoxe',
#   'igual',
#   'implantación',
#   'ir',
#   'itq',
#   'lineal',
#   'literal',
#   'lle',
#   'logo',
#   'maneira',
#   'manuel',
#   'marcha',
#   'medida',
#   'medio',
#   'menor',
#   'mentres',
#   'mesmo',
#   'modelo',
#   'momento',
#   'máis',
#   'nada',
#   'necesidade',
#   'nin',
#   'non',
#   'noso',
#   'nós',
#   'o',
#   'onde',
#   'orde',
#   'outro',
#   'outubro',
#   'para',
#   'paro',
#   'pasar',
#   'país',
#   'permitir',
#   'pero',
#   'pescar',
#   'pesqueiro',
#   'plan',
#   'poder',
#   'poema',
#   'por',
#   'porque',
#   'posibilitar',
#   'poñer',
#   'problema',
#   'proposta',
#   'provincia',
#   'publicar',
#   'punto',
#   'pór',
#   'que',
#   'quedar',
#   'quilo',
#   'realidade',
#   'reclamar',
#   'recuperación',
#   'reflectir',
#   'regulación',
#   'repartición',
#   'resposta',
#   'rosalía',
#   'saber',
#   'sardiña',
#   'saída',
#   'se',
#   'sector',
#   'semana',
#   'sen',
#   'senón',
#   'ser',
#   'seu',
#   'señoría',
#   'significativo',
#   'socioeconómico',
#   'stock',
#   'subvencionar',
#   'tanto',
#   'ter',
#   'tirado',
#   'tirar',
#   'todo',
#   'tomar',
#   'tonelada',
#   'tripulación',
#   'triste',
#   'un',
#   'unicamente',
#   'ver',
#   'vez',
#   'vir',
#   'vostede',
#   'xa',
#   'xarda',
#   'xeito',
#   'xustamente',
#   'xusto',
#   'zona',
#   'único'},
#  'ParlaMint-ES-GA_2015-02-24-DSPG098.u248': {'favor', 'ir', 'por', 'rematar'},
#  'ParlaMint-ES-GA_2015-02-24-DSPG098.u249': {'a',
#   'actividade',
#   'ano',
#   'así',
#   'aumentar',
#   'biscaíño',
#   'bocarte',
#   'cando',
#   'como',
#   'corresponder',
#   'cota',
#   'de',
#   'dereito',
#   'diminuír',
#   'dous',
#   'día',
#   'e',
#   'embarcación',
#   'entre',
#   'equilibrar',
#   'ese',
#   'esgotar',
#   'este',
#   'exemplo',
#   'facer',
#   'haber',
#   'hoxe',
#   'igual',
#   'ixa',
#   'lineal',
#   'lle',
#   'maio',
#   'marabilloso',
#   'miseria',
#   'non',
#   'nos',
#   'número',
#   'o',
#   'onde',
#   'ou',
#   'outubro',
#   'para',
#   'pero',
#   'pescar',
#   'poder',
#   'poñer',
#   'pór',
#   'que',
#   'quilo',
#   'repartición',
#   'repartir',
#   'se',
#   'seguir',
#   'ter',
#   'tonelada',
#   'total',
#   'transvasamento',
#   'tratar',
#   'un',
#   'viiic',
#   'xa',
#   'xeito',
#   'xestión',
#   'xurelo',
#   'zona',
#   'á'},
#  'ParlaMint-ES-GA_2015-02-24-DSPG098.u25': {'a',
#   'acabar',
#   'acreditar',
#   'activo',
#   'actuar',
#   'agora',
#   'aniquilar',
#   'ano',
#   'antes',
#   'apartado',
#   'apoiar',
#   'aquí',
#   'asegurar',
#   'atrever',
#   'autonomía',
#   'auténtico',
#   'axuda',
#   'aí',
#   'aínda',
#   'bng',
#   'caer',
#   'cal',
#   'cara',
#   'castelao',
#   'chegar',
#   'claro',
#   'coar',
#   'como',
#   'competencia',
#   'compravenda',
#   'comprometido',
#   'compulsivo',
#   'comunicación',
#   'con',
#   'conselleiro',
#   'contar',
#   'contemplar',
#   'conto',
#   'contrario',
#   'cousa',
#   'cumprido',
#   'cámara',
#   'cómodo',
#   'dar',
#   'de',
#   'deber',
#   'decidir',
#   'deixar',
#   'delegado',
#   'demais',
#   'deputado',
#   'derrogar',
#   'desaparecer',
#   'desaparición',
#   'desde',
#   'despois',
#   'desvergonza',
#   'dicir',
#   'director',
#   'discrecional',
#   'discrecionalidade',
#   'discriminación',
#   'dispor',
#   'dous',
#   'día',
#   'e',
#   'efectivamente',
#   'eh',
#   'electoral',
#   'en',
#   'encargar',
#   'entender',
#   'entre',
#   'entón',
#   'escoitar',
#   'ese',
#   'esperpento',
#   'esperpéntico',
#   'establecer',
#   'estado',
#   'estar',
#   'estatuto',
#   'este',
#   'eu',
#   'exclusivamente',
#   'exemplo',
#   'facer',
#   'falar',
#   'favor',
#   'feijóo',
#   'galego',
#   'galiza',
#   'goberno',
#   'grupo',
#   'haber',
#   'hemeroteca',
#   'hora',
#   'idioma',
#   'imposibilitar',
#   'incumprir',
#   'iniciativa',
#   'innumerable',
#   'insistencia',
#   'institucional',
#   'ir',
#   'iso',
#   'isto',
#   'lamentable',
#   'lección',
#   'lei',
#   'letra',
#   'levar',
#   'lexislatura',
#   'lle',
#   'logo',
#   'madrid',
#   'mais',
#   'marco',
#   'materia',
#   'media',
#   'medio',
#   'mentir',
#   'metade',
#   'millón',
#   'mirar',
#   'misiva',
#   'moito',
#   'momento',
#   'motivo',
#   'máis',
#   'múltiple',
#   'nada',
#   'nin',
#   'ningún',
#   'non',
#   'normativa',
#   'nos',
#   'nós',
#   'núñez',
#   'o',
#   'obrigar',
#   'ocasión',
#   'onde',
#   'opacidade',
#   'ou',
#   'para',
#   'parlamentario',
#   'parlamento',
#   'partido',
#   'pasivo',
#   'patria',
#   'paula',
#   'país',
#   'permitir',
#   'pesar',
#   'pobo',
#   'poder',
#   'pois',
#   'polo',
#   'popular',
#   'por',
#   'porque',
#   'posible',
#   'positivo',
#   'pouco',
#   'pouquiño',
#   'poñer',
#   'pp',
#   'practicar',
#   'prado',
#   'predicamento',
#   'predicar',
#   'presentar',
#   'presidente',
#   'prioridade',
#   'priorizan',
#   'programa',
#   'prometer',
#   'prometido',
#   'promocionar',
#   'propio',
#   'práctica',
#   'publicidade',
#   'público',
#   'que',
#   'quedar',
#   'querer',
#   'real',
#   'recurso',
#   'regulación',
#   'regular',
#   'reivindicación',
#   'relación',
#   'representante',
#   'resultar',
#   'saber',
#   'se',
#   'sector',
#   'seguir',
#   'segundo',
#   'seis',
#   'sen',
#   'ser',
#   'serie',
#   'serio',
#   'sestayo',
#   'seu',
#   'señor',
#   'si',
#   'sistematicamente',
#   'subir',
#   'só',
#   'tampouco',
#   'tamén',
#   'tanto',
#   'ter',
#   'todo',
#   'total',
#   'traer',
#   'transparencia',
#   'trato',
#   'tribuna',
#   'un',
#   'usar',
#   'verdade',
#   'vergonza',
#   'vergonzoso',
#   'vez',
#   'vir',
#   'volver',
#   'vontade',
#   'vostede',
#   'voz',
#   'vós',
#   'xa',
#   'xeito',
#   'xeral',
#   'xusta',
#   'xusto',
#   'á',
#   'único'},
#  'ParlaMint-ES-GA_2015-02-24-DSPG098.u250': {'favor', 'por', 'roda', 'señor'},
#  'ParlaMint-ES-GA_2015-02-24-DSPG098.u251': {'cantidade',
#   'corresponder',
#   'de',
#   'defensa',
#   'día',
#   'exemplo',
#   'galego',
#   'goberno',
#   'lle',
#   'noso',
#   'o',
#   'parte',
#   'pesqueiro',
#   'por',
#   'que',
#   'quilo',
#   'sector',
#   'unicamente',
#   'ver',
#   'xestión'},
#  'ParlaMint-ES-GA_2015-02-24-DSPG098.u252': {'graza',
#   'moito',
#   'roda',
#   'señor'},
#  'ParlaMint-ES-GA_2015-02-24-DSPG098.u253': {'abandono',
#   'de',
#   'deseñar',
#   'e',
#   'estratexia',
#   'graza',
#   'liquidación',
#   'literal',
#   'moito',
#   'máis',
#   'nada',
#   'noso',
#   'o',
#   'pesqueiro',
#   'que',
#   'sector',
#   'ser',
#   'ter',
#   'un'},
#  'ParlaMint-ES-GA_2015-02-24-DSPG098.u254': {'alternativa',
#   'de',
#   'esquerda',
#   'fajardo',
#   'galego',
#   'grupo',
#   'o',
#   'palabra',
#   'parlamentario',
#   'recouso',
#   'señor',
#   'ter'},
#  'ParlaMint-ES-GA_2015-02-24-DSPG098.u255': {'a',
#   'abocar',
#   'absolutamente',
#   'aceptar',
#   'acordo',
#   'acusar',
#   'ademais',
#   'afectar',
#   'agora',
#   'alegoría',
#   'algún',
#   'alimento',
#   'alternativa',
#   'ano',
#   'anterior',
#   'anuncio',
#   'apenas',
#   'apoiar',
#   'aprobar',
#   'aquel',
#   'aquí',
#   'armador',
#   'asociación',
#   'así',
#   'atacar',
#   'axuda',
#   'aínda',
#   'ben',
#   'bng',
#   'bo',
#   'cambio',
#   'cando',
#   'capacidade',
#   'capaz',
#   'captura',
#   'caso',
#   'catro',
#   'cerco',
#   'circunstancia',
#   'claramente',
#   'colombia',
#   'comisión',
#   'como',
#   'compartir',
#   'compañeiro',
#   'complicar',
#   'con',
#   'contar',
#   'continuar',
#   'controlar',
#   'conxunto',
#   'cota',
#   'cousa',
#   'crear',
#   'crer',
#   'crise',
#   'criticar',
#   'dar',
#   'de',
#   'decembro',
#   'decisión',
#   'defender',
#   'deixar',
#   'desaparecer',
#   'desaparición',
#   'dicir',
#   'dificilmente',
#   'difícil',
#   'dobre',
#   'durante',
#   'e',
#   'el',
#   'empresa',
#   'en',
#   'entregar',
#   'entrevista',
#   'escapar',
#   'escrito',
#   'ese',
#   'esmola',
#   'esmorecer',
#   'especie',
#   'esquecer',
#   'esquerda',
#   'estacada',
#   'estado',
#   'estar',
#   'este',
#   'estraño',
#   'evidente',
#   'explicable',
#   'explicar',
#   'facer',
#   'falar',
#   'falta',
#   'favor',
#   'forma',
#   'frota',
#   'fundamental',
#   'galego',
#   'galicia',
#   'goberno',
#   'grande',
#   'grupo',
#   'gustar',
#   'haber',
#   'habitual',
#   'igual',
#   'importante',
#   'industria',
#   'interesar',
#   'interese',
#   'interpretación',
#   'ir',
#   'iso',
#   'isto',
#   'literal',
#   'lle',
#   'logo',
#   'lugar',
#   'límite',
#   'madrid',
#   'malvender',
#   'manter',
#   'mariñeiro',
#   'merecer',
#   'mes',
#   'mesa',
#   'miseria',
#   'modelo',
#   'moeda',
#   'moito',
#   'momento',
#   'máis',
#   'méxico',
#   'necesario',
#   'necesidade',
#   'negociación',
#   'negociar',
#   'nin',
#   'ningún',
#   'non',
#   'noso',
#   'novo',
#   'nós',
#   'o',
#   'onde',
#   'oposición',
#   'orfo',
#   'ou',
#   'outro',
#   'oír',
#   'para',
#   'paradisíaco',
#   'parlamento',
#   'paro',
#   'partidario',
#   'partidista',
#   'partido',
#   'pata',
#   'país',
#   'pechar',
#   'pequeno',
#   'perder',
#   'perfecto',
#   'permitir',
#   'pero',
#   'persoa',
#   'pesar',
#   'pesca',
#   'pescador',
#   'pesebre',
#   'pesqueira',
#   'pesqueiro',
#   'plan',
#   'plantexaba',
#   'pobo',
#   'poder',
#   'política',
#   'político',
#   'popular',
#   'por',
#   'porque',
#   'posto',
#   'potencia',
#   'presente',
#   'presidente',
#   'prexudicar',
#   'problema',
#   'propio',
#   'proposta',
#   'provocar',
#   'que',
#   'querer',
#   'rasero',
#   'realidade',
#   'rebaixa',
#   'recibir',
#   'redeiro',
#   'respecto',
#   'resultar',
#   'risco',
#   'ruta',
#   'rédito',
#   'salvo',
#   'sardiña',
#   'saír',
#   'se',
#   'sector',
#   'sectorial',
#   'seguir',
#   'seguramente',
#   'sempre',
#   'ser',
#   'seu',
#   'señor',
#   'significar',
#   'simple',
#   'situación',
#   'soamente',
#   'socialista',
#   'supervivencia',
#   'supoñer',
#   'tampouco',
#   'tan',
#   'tanto',
#   'tarde',
#   'ter',
#   'tipo',
#   'todo',
#   'tomar',
#   'traballar',
#   'traballo',
#   'traer',
#   'tres',
#   'un',
#   'urxente',
#   'vasco',
#   'venda',
#   'vender',
#   'verdade',
#   'vez',
#   'vir',
#   'visita',
#   'vivir',
#   'votar',
#   'vulnerar',
#   'xarda',
#   'xestión',
#   'xunta',
#   'xurelo'},
#  'ParlaMint-ES-GA_2015-02-24-DSPG098.u256': {'balseiro',
#   'fajardo',
#   'graza',
#   'grupo',
#   'parlamentario',
#   'popular',
#   'señor'},
#  'ParlaMint-ES-GA_2015-02-24-DSPG098.u257': {'a',
#   'acto',
#   'ademais',
#   'agora',
#   'agresivo',
#   'alí',
#   'ano',
#   'antes',
#   'apoiar',
#   'aprobar',
#   'aquí',
#   'así',
#   'ata',
#   'autoasignarse',
#   'aínda',
#   'ben',
#   'benvido',
#   'biolóxico',
#   'bng',
#   'bo',
#   'bueno',
#   'cal',
#   'camiño',
#   'cando',
#   'cerco',
#   'certificar',
#   'certo',
#   'chegar',
#   'cinismo',
#   'comercialización',
#   'comisión',
#   'como',
#   'comunidade',
#   'con',
#   'confundir',
#   'confuso',
#   'conseguir',
#   'conselleiro',
#   'consello',
#   'consultar',
#   'contra',
#   'conxunto',
#   'cota',
#   'cousa',
#   'crear',
#   'cuestión',
#   'daquela',
#   'de',
#   'deber',
#   'decembro',
#   'decidir',
#   'deixar',
#   'demais',
#   'dentro',
#   'deputado',
#   'despois',
#   'desvantaxe',
#   'diario',
#   'dicir',
#   'día',
#   'e',
#   'efectivamente',
#   'elaboración',
#   'elite',
#   'emenda',
#   'en',
#   'engádega',
#   'entere',
#   'estar',
#   'este',
#   'estear',
#   'estudo',
#   'eu',
#   'europa',
#   'evidente',
#   'evitar',
#   'facer',
#   'falar',
#   'fin',
#   'franco',
#   'frear',
#   'frota',
#   'galego',
#   'galicia',
#   'goberno',
#   'graza',
#   'grupo',
#   'haber',
#   'hora',
#   'hoxe',
#   'ibérico',
#   'impor',
#   'importancia',
#   'incluso',
#   'incluír',
#   'industria',
#   'informe',
#   'iniciativa',
#   'isto',
#   'izar',
#   'lei',
#   'lembrar',
#   'levantar',
#   'lexislar',
#   'lle',
#   'longo',
#   'lugar',
#   'mal',
#   'mañá',
#   'me',
#   'medida',
#   'menos',
#   'mes',
#   'mesmo',
#   'meter',
#   'mixto',
#   'moción',
#   'moi',
#   'máis',
#   'nada',
#   'noite',
#   'non',
#   'nos',
#   'noso',
#   'nunca',
#   'o',
#   'obrigar',
#   'obxectivo',
#   'olvidar',
#   'outro',
#   'para',
#   'parlamento',
#   'partido',
#   'pasado',
#   'pasar',
#   'pedir',
#   'pero',
#   'pesca',
#   'pescar',
#   'pesqueiro',
#   'petición',
#   'plan',
#   'pleno',
#   'poder',
#   'político',
#   'popular',
#   'por',
#   'porque',
#   'portugal',
#   'posibilidade',
#   'posición',
#   'pouco',
#   'precisamente',
#   'preocupar',
#   'presidente',
#   'pretender',
#   'previo',
#   'primeiro',
#   'problema',
#   'profesional',
#   'propaganda',
#   'proposición',
#   'proposta',
#   'puro',
#   'que',
#   'quedar',
#   'quen',
#   'querer',
#   'recorte',
#   'recuperación',
#   'recurso',
#   'redución',
#   'referencia',
#   'respaldar',
#   'retrasar',
#   'rexeitar',
#   'saber',
#   'sardiña',
#   'se',
#   'segundo',
#   'sen',
#   'senón',
#   'ser',
#   'sesión',
#   'seu',
#   'señor',
#   'señoría',
#   'si',
#   'situación',
#   'sobre',
#   'socialista',
#   'socioeconómico',
#   'solemnizar',
#   'supor',
#   'só',
#   'tac',
#   'tamén',
#   'tema',
#   'ter',
#   'terceiro',
#   'todo',
#   'traballar',
#   'traer',
#   'tranquilo',
#   'transformación',
#   'tratar',
#   'tres',
#   'un',
#   'unilateral',
#   'val',
#   'ver',
#   'verdade',
#   'vez',
#   'viiib',
#   'vostede',
#   'votar',
#   'xa',
#   'xestión',
#   'xogar',
#   'xunta',
#   'zona',
#   'á'},
#  'ParlaMint-ES-GA_2015-02-24-DSPG098.u258': {'favor', 'ir', 'por', 'rematar'},
#  ...}
