# %%
# !pip install matplotlib seaborn
# !pip install umap-learn -i https: // mirrors.ustc.edu.cn/pypi/web/simple
# Out:
# Requirement already satisfied: matplotlib in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (3.7.1)
# Requirement already satisfied: seaborn in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (0.12.2)
# Collecting umap-learn
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 1.6 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.7 in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: contourpy>=1.0.1 in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22 in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: scipy>=1.0 in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (from umap-learn) (1.10.1)
# Collecting numba>=0.49
#   Downloading numba-0.57.0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 34.8 MB/s eta 0:00:0000:0100:01
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.8 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (from umap-learn) (4.65.0)
# Requirement already satisfied: zipp>=3.1.0 in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Collecting llvmlite<0.41,>=0.40.0dev0
#   Downloading llvmlite-0.40.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 24.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pytz>=2020.1 in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: joblib>=0.11 in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (from pynndescent>=0.5->umap-learn) (1.2.0)
# Requirement already satisfied: six>=1.5 in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /storage/vidklopcic/anaconda3/envs/dhh23/lib/python3.9/site-packages (from scikit-learn>=0.22->umap-learn) (3.1.0)
# Building wheels for collected packages: umap-learn, pynndescent
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82813 sha256=5cd5f002b1f29928b6e5ce31d23112183238334c222688d2cec9445c35d6aabb
#   Stored in directory: /storage/vidklopcic/.cache/pip/wheels/f4/3e/1c/596d0a463d17475af648688443fa4846fef624d1390339e7e9
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55623 sha256=8dea213d10e85b27bab0e2752cfccf63b7deb3c1731575bcd731c9e6d2ab94e1
#   Stored in directory: /storage/vidklopcic/.cache/pip/wheels/12/f9/4d/ec5ad1c823c710fcc4473669fdcffc8891f4bc398c841af22e
# Successfully built umap-learn pynndescent
# Installing collected packages: llvmlite, numba, pynndescent, umap-learn
# Successfully installed llvmlite-0.40.0 numba-0.57.0 pynndescent-0.5.10 umap-learn-0.5.3

# %%
import pickle

embeddings = pickle.load(open('artefacts/bojan/ParlaMint_GB_commons_aggregated_embeddings.pkl', 'rb'))

# %%
import pandas as pd

speeches_subset = pd.read_feather('artefacts/bojan/gb_commons_embeedings_subset.feather')
embeddings_subset = [embeddings[i] for i in speeches_subset.ID]
speeches_subset
# Out:
#         index                                    ID  \
# 0      407774    ParlaMint-GB_2019-03-26-commons.u1
# 1      407775    ParlaMint-GB_2019-03-26-commons.u2
# 2      407776    ParlaMint-GB_2019-03-26-commons.u3
# 3      407777    ParlaMint-GB_2019-03-26-commons.u4
# 4      407778    ParlaMint-GB_2019-03-26-commons.u5
# ...       ...                                   ...
# 41858  472777  ParlaMint-GB_2019-01-22-commons.u384
# 41859  472778  ParlaMint-GB_2019-01-22-commons.u385
# 41860  472779  ParlaMint-GB_2019-01-22-commons.u386
# 41861  472780  ParlaMint-GB_2019-01-22-commons.u387
# 41862  472781  ParlaMint-GB_2019-01-22-commons.u388
#
#                                                    Title        Date  \
# 0      Minutes of the House of Commons, Daily Session...  2019-03-26
# 1      Minutes of the House of Commons, Daily Session...  2019-03-26
# 2      Minutes of the House of Commons, Daily Session...  2019-03-26
# 3      Minutes of the House of Commons, Daily Session...  2019-03-26
# 4      Minutes of the House of Commons, Daily Session...  2019-03-26
# ...                                                  ...         ...
# 41858  Minutes of the House of Commons, Daily Session...  2019-01-22
# 41859  Minutes of the House of Commons, Daily Session...  2019-01-22
# 41860  Minutes of the House of Commons, Daily Session...  2019-01-22
# 41861  Minutes of the House of Commons, Daily Session...  2019-01-22
# 41862  Minutes of the House of Commons, Daily Session...  2019-01-22
#
#               Body  Term  Session  Meeting     Sitting  Agenda  ...  \
# 0      Lower house    57      NaN      NaN  2019-03-26     NaN  ...
# 1      Lower house    57      NaN      NaN  2019-03-26     NaN  ...
# 2      Lower house    57      NaN      NaN  2019-03-26     NaN  ...
# 3      Lower house    57      NaN      NaN  2019-03-26     NaN  ...
# 4      Lower house    57      NaN      NaN  2019-03-26     NaN  ...
# ...            ...   ...      ...      ...         ...     ...  ...
# 41858  Lower house    57      NaN      NaN  2019-01-22     NaN  ...
# 41859  Lower house    57      NaN      NaN  2019-01-22     NaN  ...
# 41860  Lower house    57      NaN      NaN  2019-01-22     NaN  ...
# 41861  Lower house    57      NaN      NaN  2019-01-22     NaN  ...
# 41862  Lower house    57      NaN      NaN  2019-01-22     NaN  ...
#
#       Speaker_MP Speaker_Minister Speaker_party Speaker_party_name  \
# 0             MP                -           LAB             Labour
# 1             MP                -           CON       Conservative
# 2             MP                -           LAB             Labour
# 3             MP                -           CON       Conservative
# 4             MP                -           CON       Conservative
# ...          ...              ...           ...                ...
# 41858         MP                -           LAB             Labour
# 41859         MP                -           CON       Conservative
# 41860         MP                -           LAB             Labour
# 41861         MP                -           CON       Conservative
# 41862         MP                -           CON       Conservative
#
#       Party_status                   Speaker_name Speaker_gender  \
# 0       Opposition             Powell, Lucy Maria              F
# 1             None    Hancock, Matthew John David              M
# 2       Opposition             Powell, Lucy Maria              F
# 3             None    Hancock, Matthew John David              M
# 4             None  Crouch, Tracey Elizabeth Anne              F
# ...            ...                            ...            ...
# 41858   Opposition        Foxcroft, Victoria Jane              F
# 41859         None                 Zahawi, Nadhim              M
# 41860   Opposition        Foxcroft, Victoria Jane              F
# 41861         None                 Zahawi, Nadhim              M
# 41862         None          Laing, Eleanor Fulton              F
#
#       Speaker_birth                                             speech  \
# 0                 -  1. What steps he is taking to help ensure bett...
# 1                 -  The Department of Health and Social Care works...
# 2                 -  I thank the Secretary of State very much for t...
# 3                 -  I agree with the hon. Lady on both counts. My ...
# 4                 -  On Friday, I met two clinical commissioning gr...
# ...             ...                                                ...
# 41858             -  Could the Minister outline what funding is pro...
# 41859             -  I am grateful to the hon. Lady for that interv...
# 41860             -  The Minister said that he would return to the ...
# 41861             -  I am grateful to the hon. Lady for coming back...
# 41862             -  Order. Before I put the Question, I must infor...
#
#       Date_datetime
# 0        2019-03-26
# 1        2019-03-26
# 2        2019-03-26
# 3        2019-03-26
# 4        2019-03-26
# ...             ...
# 41858    2019-01-22
# 41859    2019-01-22
# 41860    2019-01-22
# 41861    2019-01-22
# 41862    2019-01-22
#
# [41863 rows x 22 columns]

# %%
import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline
sns.set(style='white', context='notebook', rc={'figure.figsize': (14, 10)})

# %%
from umap import UMAP

reducer = UMAP(n_neighbors=100,
               min_dist=1,
               n_components=2,
               metric='cosine')

# %%
embedding = reducer.fit_transform(embeddings_subset)

# %%
subset = speeches_subset.Speaker_party_name
speaker_parties = subset.unique()
color_map = {v: i if i < 2 else 2 for i, v in enumerate(speaker_parties)}
print(color_map)
color_map = [color_map[x] for x in subset]
# Out:
# {'Labour': 0, 'Conservative': 1, 'Scottish National Party': 2, 'Democratic Unionist Party': 2, 'Liberal Democrat': 2, 'Plaid Cymru': 2, 'Independent': 2, 'Change UK - The Independent Group;The Independent Group for Change': 2, 'Green Party': 2, 'The Independent Group for Change;Change UK - The Independent Group': 2, 'Conservative;Independent': 2}

# %%
# plt.clf()
sentences = [s for s in speeches_subset.speech]
c = [sns.color_palette("husl", 3)[x] for x in color_map]
# plt.scatter(
#     embedding[:, 0],
#     embedding[:, 1],
#     c=c,
#     s=0.3,
#     marker='.',
#     edgecolors='none',
# )
# plt.gca().set_aspect('equal', 'datalim')
# plt.title('UMAP projection of the GB Commons dataset', fontsize=24);
# plt.savefig('artefacts/bojan/umap.pdf')
with open('artefacts/bojan/umap.pkl', 'wb') as f:
    pickle.dump([
        embedding,
        c,
        sentences
    ], f)
# plt.show()

# %%
y_min = -20
y_max = -15
x_min = -15
x_max = 0
sentences = [i for i in range(len(speeches_subset)) if
             y_min < embedding[i, 3] < y_max and x_min < embedding[i, 2] < x_max]
speeches_subset.iloc[sentences].speech
# Out:
# 21       The hon. Gentleman knows that I wrote to him o...
# 31       The hon. Gentleman can believe everything my r...
# 98       The hon. Lady makes some excellent points and ...
# 114      The hon. Gentleman asked a number of questions...
# 118      The hon. Gentleman is right: early diagnosis o...
#                                ...
# 41806    The hon. Gentleman has been a good campaigner ...
# 41814    The hon. Gentleman is right: this will be a pu...
# 41816    The hon. Gentleman makes a good point. In prot...
# 41829    The hon. Gentleman is absolutely right. Aid wo...
# 41855    The hon. Gentleman has raised a vital issue. G...
# Name: speech, Length: 1765, dtype: object
